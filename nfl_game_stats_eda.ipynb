# %%
# Import packages

import pandas as pd 
import numpy as np 
import os

# %%
# Check current directory
os.getcwd()
# Out:
# 'C:\\Users\\imacd_0odruq3\\Documents\\sports_gambling\\sports_gambling_algorithm'

# %%
# Read in data files

raw_data = pd.read_csv('C:\\Users\\imacd_0odruq3\\Documents\\sports_gambling\\data\\nfl_elo.csv')

# %%
# Look at data files

raw_data.head(50)
# Out:
#           date  season  neutral playoff team1 team2  elo1_pre  elo2_pre  \
# 0   1920-09-26    1920        0     NaN   RII   STP  1503.947  1300.000
# 1   1920-10-03    1920        0     NaN   CBD   PTQ  1504.688  1300.000
# 2   1920-10-03    1920        0     NaN   CHI   MUT  1368.333  1300.000
# 3   1920-10-03    1920        0     NaN   RCH   ABU  1503.420  1300.000
# 4   1920-10-03    1920        0     NaN   RII   MUN  1516.108  1478.004
# 5   1920-10-03    1920        0     NaN   DAY   COL  1493.002  1504.908
# 6   1920-10-03    1920        0     NaN   BFF   WBU  1478.004  1300.000
# 7   1920-10-03    1920        0     NaN   AKR   WHE  1503.420  1300.000
# 8   1920-10-10    1920        0     NaN   DAY   CTI  1515.434  1464.506
# 9   1920-10-10    1920        0     NaN   CBD   TLM  1516.803  1300.000
# 10  1920-10-10    1920        0     NaN   RCH   FTP  1510.934  1300.000
# 11  1920-10-10    1920        0     NaN   RII   HAM  1542.135  1444.259
# ...
