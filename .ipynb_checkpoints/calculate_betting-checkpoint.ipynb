# %%
# Import packages

import pandas as pd 
import numpy as np 
import os
from bs4 import BeautifulSoup
import time
import requests
import nfl_data_py as nfl
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet

import pickle
from joblib import dump, load

import warnings

# Set certain settings for the notebook
pd.set_option("display.max_columns", None)

warnings.filterwarnings("ignore")

# %%
# Update before running

current_season = 2022
current_week = 1

# %%
# Get odds for this week's games 

# Manually Inputted
# While not ideal, manually inputting the odds in doesn't take too much time/effort
# In the future, want to create a web scraping bot to automate getting the necessary odds data
# For now, this will have to do

current_week_odds = pd.read_csv('../data/current_week_data.csv')
current_week_odds
# Out:
#     Unnamed: 0  season  week away home  away_moneyline  home_moneyline  \
# 0       202211    2022     1  BUF  LAR            -135             115
# 1       202212    2022     1  BAL  NYJ            -295             245
# 2       202213    2022     1   SF  CHI            -295             245
# 3       202214    2022     1  IND  HOU            -390             320
# 4       202215    2022     1  PIT  CIN             240            -285
# 5       202216    2022     1  PHI  DET            -195             165
# 6       202217    2022     1  CLE  CAR             120            -140
# 7       202218    2022     1   NO  ATL            -230             195
# 8       202219    2022     1   NE  MIA             135            -155
# 9      2022110    2022     1  JAX  WAS             140            -165
# 10     2022111    2022     1  NYG  TEN             210            -250
# 11     2022112    2022     1   KC  ARI            -205             175
# 12     2022113    2022     1   GB  MIN            -120             100
# 13     2022114    2022     1   LV  LAC             155            -180
# 14     2022115    2022     1   TB  DAL            -120             100
# 15     2022116    2022     1  DEN  SEA            -260             220
#
#     away_spread  home_spread  over_under            home_full_name  \
# 0          -2.5          2.5        52.5          Los Angeles Rams
# 1          -7.0          7.0        44.5             New York Jets
# 2          -7.0          7.0        41.5             Chicago Bears
# 3          -8.0          8.0        46.0            Houston Texans
# 4           6.5         -6.5        44.0        Cincinnati Bengals
# 5          -4.0          4.0        48.5             Detroit Lions
# 6           2.5         -2.5        41.5         Carolina Panthers
# 7          -5.5          5.5        42.5           Atlanta Falcons
# 8           3.0         -3.0        46.5            Miami Dolphins
# 9           3.0         -3.0        44.0  Washington Football Team
# 10          5.5         -5.5        43.5          Tennessee Titans
# 11         -4.5          4.5        53.5         Arizona Cardinals
# 12         -1.0          1.0        48.0         Minnesota Vikings
# 13          3.5         -3.5        52.5      Los Angeles Chargers
# 14         -1.5          1.5        50.0            Dallas Cowboys
# 15         -6.5          6.5        43.0          Seattle Seahawks
#
#           away_full_name           home_qb          away_qb
# 0          Buffalo Bills  Matthew Stafford       Josh Allen
# 1       Baltimore Ravens       Zach Wilson    Lamar Jackson
# 2    San Francisco 49ers     Justin Fields       Trey Lance
# 3     Indianapolis Colts       Davis Mills        Matt Ryan
# 4    Pittsburgh Steelers        Joe Burrow   Mitch Trubisky
# 5    Philadelphia Eagles        Jared Goff      Jalen Hurts
# 6       Cleveland Browns    Baker Mayfield  Jacoby Brissett
# 7     New Orleans Saints    Marcus Mariota   Jameis Winston
# 8   New England Patriots    Tua Tagovailoa        Mac Jones
# 9   Jacksonville Jaguars      Carson Wentz  Trevor Lawrence
# 10       New York Giants    Ryan Tannehill     Daniel Jones
# 11    Kansas City Chiefs      Kyler Murray  Patrick Mahomes
# 12     Green Bay Packers      Kirk Cousins    Aaron Rodgers
# 13     Las Vegas Raiders    Justin Herbert       Derek Carr
# 14  Tampa Bay Buccaneers      Dak Prescott        Tom Brady
# 15        Denver Broncos        Geno Smith   Russell Wilson

# %%
# Get predictive stats dataframe 

predictive_stats = pd.read_csv('../data/predictive_stats_df.csv')
predictive_stats = predictive_stats[(predictive_stats.season == current_season) & (predictive_stats.week == current_week)]
predictive_stats
# Out:
#      Unnamed: 0  season  week home away            home_full_name  \
# 239         285    2022     1  LAR  BUF          Los Angeles Rams
# 240         286    2022     1  NYJ  BAL             New York Jets
# 241         287    2022     1  CHI   SF             Chicago Bears
# 242         288    2022     1  HOU  IND            Houston Texans
# 243         290    2022     1  DET  PHI             Detroit Lions
# 244         291    2022     1  CAR  CLE         Carolina Panthers
# 245         293    2022     1  MIA   NE            Miami Dolphins
# 246         294    2022     1  WAS  JAX  Washington Football Team
# 247         295    2022     1  TEN  NYG          Tennessee Titans
# 248         296    2022     1  ARI   KC         Arizona Cardinals
# 249         297    2022     1  MIN   GB         Minnesota Vikings
# 250         298    2022     1  LAC   LV      Los Angeles Chargers
# 251         299    2022     1  DAL   TB            Dallas Cowboys
# 252         300    2022     1  SEA  DEN          Seattle Seahawks
#
#            away_full_name  season_home  week_home       team_full_name_home  \
# 239         Buffalo Bills         2022          1          Los Angeles Rams
# 240      Baltimore Ravens         2022          1             New York Jets
# 241   San Francisco 49ers         2022          1             Chicago Bears
# 242    Indianapolis Colts         2022          1            Houston Texans
# 243   Philadelphia Eagles         2022          1             Detroit Lions
# 244      Cleveland Browns         2022          1         Carolina Panthers
# 245  New England Patriots         2022          1            Miami Dolphins
# 246  Jacksonville Jaguars         2022          1  Washington Football Team
# 247       New York Giants         2022          1          Tennessee Titans
# 248    Kansas City Chiefs         2022          1         Arizona Cardinals
# 249     Green Bay Packers         2022          1         Minnesota Vikings
# 250     Las Vegas Raiders         2022          1      Los Angeles Chargers
# 251  Tampa Bay Buccaneers         2022          1            Dallas Cowboys
# 252        Denver Broncos         2022          1          Seattle Seahawks
#
#               qb_home  total_pass_attempts_last_6_avg_home  \
# 239  Matthew Stafford                            35.000000
# 240       Zach Wilson                            29.833333
# 241     Justin Fields                            32.333333
# 242       Davis Mills                            35.000000
# 243        Jared Goff                            31.000000
# 244    Baker Mayfield                            34.333333
# 245    Tua Tagovailoa                            31.000000
# 246      Carson Wentz                            27.166667
# 247    Ryan Tannehill                            27.833333
# 248      Kyler Murray                            42.666667
# 249      Kirk Cousins                            31.500000
# 250    Justin Herbert                            39.833333
# 251      Dak Prescott                            38.166667
# 252        Geno Smith                            25.666667
#
#      total_passing_yards_last_6_avg_home  completions_last_6_avg_home  \
# 239                           295.833333                    24.333333
# 240                           170.166667                    15.833333
# 241                           239.833333                    19.500000
# 242                           261.666667                    24.333333
# 243                           220.833333                    21.166667
# 244                           195.666667                    18.500000
# 245                           197.000000                    20.833333
# 246                           180.166667                    16.500000
# 247                           196.666667                    19.333333
# 248                           267.333333                    27.000000
# 249                           245.000000                    19.666667
# 250                           298.333333                    25.666667
# 251                           277.000000                    25.166667
# 252                           190.333333                    18.333333
#
#      passing_epa_last_6_avg_home  pass_tds_last_6_avg_home  \
# 239                    10.260848                  2.333333
# 240                    -6.237789                  0.833333
# 241                    -5.230476                  1.166667
# 242                     0.799098                  1.833333
# 243                     1.761633                  2.000000
# 244                    -7.172021                  1.500000
# 245                    -1.081374                  1.166667
# 246                    -2.936697                  1.500000
# 247                     1.246073                  1.333333
# 248                    -5.197716                  0.833333
# 249                    -0.122909                  2.000000
# 250                     8.596846                  2.333333
# 251                     7.764728                  2.666667
# 252                    -2.019755                  1.333333
#
#      avg_cpoe_last_6_avg_home  qb_epa_last_6_avg_home  \
# 239                  5.549945               10.448003
# 240                -12.807888               -5.315712
# 241                 -0.638040               -3.097366
# 242                  3.052710                0.345089
# 243                  0.599770                1.118470
# 244                 -8.695001               -5.817175
# 245                  0.909200               -0.487964
# 246                 -5.768720               -0.781519
# 247                  4.460529                1.941193
# 248                 -3.150067               -4.249965
# 249                 -1.282628                0.266394
# 250                  2.257902                9.578604
# 251                 -0.139873                7.616969
# 252                  8.436912               -0.880255
#
#      sacks_allowed_last_6_avg_home  interceptions_thrown_last_6_avg_home  \
# 239                       2.166667                              1.166667
# 240                       3.666667                              0.166667
# 241                       3.166667                              1.166667
# 242                       2.333333                              0.500000
# 243                       2.166667                              0.333333
# 244                       3.833333                              1.666667
# 245                       2.166667                              0.666667
# 246                       2.333333                              0.666667
# 247                       2.500000                              0.666667
# 248                       2.333333                              0.833333
# 249                       2.333333                              0.833333
# 250                       1.666667                              0.833333
# 251                       2.833333                              0.500000
# 252                       4.333333                              0.000000
#
#      qb_value_pre_last_6_avg_home  qb_adj_last_6_avg_home  \
# 239                    185.952558                2.185934
# 240                     53.981165              -29.368982
# 241                     65.830061              -29.335813
# 242                     93.987074              -61.938128
# 243                    128.494926               -7.699301
# 244                    115.840791              -20.929775
# 245                    148.866795               12.362190
# 246                    140.516197                0.235844
# 247                    140.133965              -20.168425
# 248                    219.071927                7.536507
# 249                    213.676668                6.791690
# 250                    241.399465               21.552983
# 251                    202.468367               -3.131229
# 252                    120.962962              -62.189861
#
#      total_rushes_last_6_avg_home  total_rush_yards_last_6_avg_home  \
# 239                     27.000000                         78.500000
# 240                     22.666667                        120.333333
# 241                     26.500000                        105.000000
# 242                     25.333333                         94.000000
# 243                     27.000000                        111.500000
# 244                     23.333333                         95.333333
# 245                     31.500000                        120.500000
# 246                     25.166667                        114.166667
# 247                     32.500000                        143.333333
# 248                     23.000000                        108.500000
# 249                     25.166667                        112.166667
# 250                     28.666667                        117.500000
# 251                     25.833333                        110.000000
# 252                     27.666667                        176.500000
#
#      rushing_epa_last_6_avg_home  rush_tds_last_6_avg_home  \
# 239                    -9.442989                  0.500000
# 240                     0.089632                  1.000000
# 241                    -0.935647                  0.833333
# 242                    -2.690961                  0.333333
# 243                    -4.345262                  0.500000
# 244                    -2.253184                  0.833333
# 245                    -3.205870                  0.833333
# 246                     0.722648                  0.833333
# 247                    -1.003350                  1.166667
# 248                     0.598950                  0.833333
# 249                    -0.331468                  0.666667
# 250                    -2.277712                  1.333333
# 251                     0.367532                  0.833333
# 252                     5.517706                  1.666667
#
#      fumbles_last_6_avg_home  lost_fumbles_last_6_avg_home  \
# 239                 0.833333                      0.833333
# 240                 0.500000                      0.333333
# 241                 1.166667                      0.500000
# 242                 0.500000                      0.166667
# 243                 1.000000                      0.500000
# 244                 1.333333                      0.500000
# 245                 1.500000                      0.500000
# 246                 1.333333                      0.500000
# 247                 1.000000                      0.500000
# 248                 0.833333                      0.166667
# 249                 1.000000                      0.166667
# 250                 0.666667                      0.666667
# 251                 2.000000                      0.333333
# 252                 1.000000                      0.500000
#
#      ypc_last_6_avg_home  total_rushes_allowed_last_6_avg_home  \
# 239             2.884288                             22.166667
# 240             4.908638                             34.500000
# 241             4.017167                             29.166667
# 242             3.623237                             31.500000
# 243             4.214368                             28.333333
# 244             4.063362                             28.666667
# 245             3.787473                             24.833333
# 246             4.380327                             29.166667
# 247             4.345469                             16.500000
# 248             4.733514                             28.500000
# 249             4.130652                             27.833333
# 250             4.036530                             27.833333
# 251             4.128461                             27.500000
# 252             6.237232                             25.666667
#
#      total_rush_yards_allowed_last_6_avg_home  \
# 239                                 90.333333
# 240                                157.333333
# 241                                137.500000
# 242                                155.000000
# 243                                138.333333
# 244                                114.166667
# 245                                112.000000
# 246                                127.333333
# 247                                 55.333333
# 248                                121.666667
# 249                                124.333333
# 250                                128.000000
# 251                                127.000000
# 252                                 93.833333
#
#      rush_tds_allowed_last_6_avg_home  \
# 239                          0.666667
# 240                          1.333333
# 241                          0.666667
# 242                          1.333333
# 243                          1.333333
# 244                          1.333333
# 245                          1.166667
# 246                          1.000000
# 247                          0.500000
# 248                          0.500000
# 249                          0.666667
# 250                          1.166667
# 251                          0.666667
# 252                          1.000000
#
#      total_pass_attempts_allowed_last_6_avg_home  \
# 239                                    35.500000
# 240                                    34.500000
# 241                                    22.666667
# 242                                    30.000000
# 243                                    34.500000
# 244                                    31.833333
# 245                                    27.500000
# 246                                    33.833333
# 247                                    34.833333
# 248                                    28.000000
# 249                                    41.000000
# 250                                    36.166667
# 251                                    33.833333
# 252                                    36.666667
#
#      passing_yards_allowed_last_6_avg_home  \
# 239                             250.666667
# 240                             259.500000
# 241                             167.666667
# 242                             250.666667
# 243                             259.166667
# 244                             235.000000
# 245                             175.333333
# 246                             245.500000
# 247                             257.833333
# 248                             244.500000
# 249                             287.000000
# 250                             265.166667
# 251                             198.333333
# 252                             271.666667
#
#      completions_allowed_last_6_avg_home  pass_tds_allowed_last_6_avg_home  \
# 239                            22.000000                          1.166667
# 240                            22.666667                          1.500000
# 241                            14.333333                          2.166667
# 242                            20.166667                          1.666667
# 243                            23.166667                          2.166667
# 244                            21.500000                          1.666667
# 245                            15.166667                          0.500000
# 246                            22.000000                          1.333333
# 247                            22.500000                          0.666667
# 248                            19.333333                          2.666667
# 249                            27.333333                          1.833333
# 250                            22.166667                          1.833333
# 251                            18.666667                          1.166667
# 252                            24.666667                          1.500000
#
#      avg_cpoe_allowed_last_6_avg_home  sacks_last_6_avg_home  \
# 239                         -6.185407               3.333333
# 240                          5.798890               1.333333
# 241                         -2.300224               2.833333
# 242                          3.565604               1.166667
# 243                          1.633937               2.333333
# 244                          5.891009               1.500000
# 245                         -8.186567               4.166667
# 246                          0.073661               2.666667
# 247                         -1.920058               3.833333
# 248                          3.380349               1.666667
# 249                          0.133135               3.000000
# 250                         -2.192228               2.333333
# 251                         -8.631174               2.500000
# 252                         -1.399329               2.666667
#
#      fumbles_forced_last_6_avg_home  interceptions_last_6_avg_home  \
# 239                        0.500000                       1.166667
# 240                        0.500000                       0.500000
# 241                        0.833333                       0.500000
# 242                        0.333333                       0.500000
# 243                        0.666667                       0.500000
# 244                        0.500000                       0.166667
# 245                        0.166667                       1.166667
# 246                        0.166667                       0.833333
# 247                        0.500000                       1.333333
# 248                        0.833333                       0.166667
# 249                        1.000000                       1.166667
# 250                        1.000000                       0.666667
# 251                        0.833333                       1.333333
# 252                        0.333333                       1.000000
#
#      fumbles_recovered_last_6_avg_home  special_teams_epa_last_6_avg_home  \
# 239                           0.333333                           0.297185
# 240                           0.166667                           1.889893
# 241                           0.333333                           3.106423
# 242                           0.333333                           2.201746
# 243                           0.500000                           0.138419
# 244                           0.166667                          -2.018624
# 245                           0.166667                          -0.702165
# 246                           0.166667                          -0.761191
# 247                           0.000000                           0.204768
# 248                           0.500000                          -0.529648
# 249                           0.500000                          -1.528359
# 250                           0.666667                           1.254415
# 251                           0.666667                          -0.137074
# 252                           0.000000                           0.081955
#
#      passing_epa_def_last_6_avg_home  rushing_epa_def_last_6_avg_home  \
# 239                         5.598976                         0.571105
# 240                        -7.033129                        -1.404172
# 241                         1.616041                        -0.947264
# 242                        -8.274039                         0.286692
# 243                        -2.797200                        -3.563391
# 244                        -7.360280                         1.345068
# 245                        12.794993                        -0.965138
# 246                        -1.225379                         0.549484
# 247                         5.089917                         2.292221
# 248                       -11.559317                         4.876656
# 249                         4.608793                         0.426383
# 250                         0.476948                         0.714408
# 251                         8.500792                         0.124583
# 252                        -1.112985                         2.781331
#
#      season_away  week_away   team_full_name_away          qb_away  \
# 239         2022          1         Buffalo Bills       Josh Allen
# 240         2022          1      Baltimore Ravens    Lamar Jackson
# 241         2022          1   San Francisco 49ers       Trey Lance
# 242         2022          1    Indianapolis Colts        Matt Ryan
# 243         2022          1   Philadelphia Eagles      Jalen Hurts
# 244         2022          1      Cleveland Browns  Jacoby Brissett
# 245         2022          1  New England Patriots        Mac Jones
# 246         2022          1  Jacksonville Jaguars  Trevor Lawrence
# 247         2022          1       New York Giants     Daniel Jones
# 248         2022          1    Kansas City Chiefs  Patrick Mahomes
# 249         2022          1     Green Bay Packers    Aaron Rodgers
# 250         2022          1     Las Vegas Raiders       Derek Carr
# 251         2022          1  Tampa Bay Buccaneers        Tom Brady
# 252         2022          1        Denver Broncos   Russell Wilson
#
#      total_pass_attempts_last_6_avg_away  total_passing_yards_last_6_avg_away  \
# 239                            36.333333                           256.500000
# 240                            39.333333                           250.833333
# 241                            26.000000                           220.500000
# 242                            30.333333                           225.166667
# 243                            29.833333                           207.500000
# 244                            39.600000                           249.800000
# 245                            30.166667                           207.666667
# 246                            33.833333                           212.000000
# 247                            34.666667                           197.166667
# 248                            38.666667                           307.666667
# 249                            34.666667                           269.166667
# 250                            38.333333                           242.500000
# 251                            43.166667                           297.000000
# 252                            29.833333                           217.333333
#
#      completions_last_6_avg_away  passing_epa_last_6_avg_away  \
# 239                    22.166667                    10.121293
# 240                    24.500000                    -7.432662
# 241                    15.500000                     0.827978
# 242                    19.833333                    -4.410090
# 243                    17.333333                    -1.249661
# 244                    24.800000                    -1.669022
# 245                    18.500000                     2.704279
# 246                    21.333333                    -4.020721
# 247                    22.166667                    -6.117894
# 248                    27.666667                    12.345398
# 249                    25.166667                     6.848385
# 250                    25.333333                    -2.916910
# 251                    27.666667                     4.112050
# 252                    19.166667                     2.915327
#
#      pass_tds_last_6_avg_away  avg_cpoe_last_6_avg_away  \
# 239                  2.833333                  0.503211
# 240                  1.333333                 -3.194547
# 241                  1.000000                 -1.090079
# 242                  0.666667                  4.406206
# 243                  0.666667                 -2.221603
# 244                  1.000000                 -0.357827
# 245                  1.333333                 -2.953377
# 246                  0.500000                 -2.988697
# 247                  1.000000                 -0.079622
# 248                  3.166667                  7.299211
# 249                  2.500000                  6.658265
# 250                  1.166667                  1.632092
# 251                  1.666667                  0.860289
# 252                  2.166667                  2.060490
#
#      qb_epa_last_6_avg_away  sacks_allowed_last_6_avg_away  \
# 239               16.121521                       1.166667
# 240               -4.819948                       4.166667
# 241               -0.957875                       1.500000
# 242               -4.837249                       3.166667
# 243                1.585695                       1.833333
# 244               -0.920403                       3.200000
# 245                2.183288                       1.166667
# 246               -3.613128                       2.000000
# 247               -6.282377                       2.500000
# 248               14.802297                       2.000000
# 249                7.507561                       2.500000
# 250               -1.978149                       2.666667
# 251                3.708749                       2.166667
# 252                3.657537                       1.833333
#
#      interceptions_thrown_last_6_avg_away  qb_value_pre_last_6_avg_away  \
# 239                              0.666667                    250.918899
# 240                              1.333333                    208.982206
# 241                              1.000000                    111.206080
# 242                              0.166667                    132.117600
# 243                              1.000000                    167.924280
# 244                              0.600000                    127.309115
# 245                              1.166667                    127.180840
# 246                              1.166667                     75.915923
# 247                              1.000000                    132.864106
# 248                              0.500000                    255.537148
# 249                              0.333333                    261.377755
# 250                              1.000000                    170.047446
# 251                              0.500000                    247.067794
# 252                              0.500000                    150.775662
#
#      qb_adj_last_6_avg_away  total_rushes_last_6_avg_away  \
# 239                6.162398                     28.666667
# 240                3.860952                     26.166667
# 241              -24.249236                     29.333333
# 242              -19.388389                     29.833333
# 243                9.337325                     32.333333
# 244               -8.428220                     25.333333
# 245               -0.802228                     29.000000
# 246              -18.523269                     22.333333
# 247               -0.449057                     26.666667
# 248               11.727024                     26.333333
# 249               19.032192                     24.333333
# 250               -7.418971                     24.500000
# 251               11.343834                     22.833333
# 252               -6.760981                     29.166667
#
#      total_rush_yards_last_6_avg_away  rushing_epa_last_6_avg_away  \
# 239                        155.000000                     7.002993
# 240                        137.000000                     0.546682
# 241                        119.666667                    -3.701814
# 242                        153.000000                     2.631101
# 243                        152.833333                     1.808946
# 244                        125.000000                     0.930937
# 245                        144.500000                     2.382208
# 246                         82.333333                    -3.847259
# 247                        115.166667                    -1.353449
# 248                        141.666667                     3.149549
# 249                        115.833333                     3.373639
# 250                        111.500000                    -0.694078
# 251                         97.333333                    -1.027712
# 252                        127.166667                    -1.463466
#
#      rush_tds_last_6_avg_away  fumbles_last_6_avg_away  \
# 239                  1.666667                 0.500000
# 240                  1.000000                 1.166667
# 241                  0.666667                 0.666667
# 242                  1.000000                 1.000000
# 243                  1.333333                 1.000000
# 244                  0.500000                 0.500000
# 245                  1.666667                 0.833333
# 246                  0.500000                 0.833333
# 247                  0.166667                 1.333333
# 248                  0.833333                 1.166667
# 249                  1.000000                 0.833333
# 250                  0.500000                 2.333333
# 251                  1.333333                 0.333333
# 252                  1.166667                 0.500000
#
#      lost_fumbles_last_6_avg_away  ypc_last_6_avg_away  \
# 239                      0.000000             5.349456
# 240                      0.666667             4.946809
# 241                      0.000000             3.939915
# 242                      0.666667             5.102139
# 243                      0.166667             4.755367
# 244                      0.500000             4.800953
# 245                      0.333333             4.900958
# 246                      0.500000             3.411034
# 247                      0.833333             4.414966
# 248                      0.166667             5.490086
# 249                      0.333333             4.687136
# 250                      1.333333             4.658424
# 251                      0.333333             4.254320
# 252                      0.333333             4.102993
#
#      total_rushes_allowed_last_6_avg_away  \
# 239                             23.833333
# 240                             23.333333
# 241                             24.166667
# 242                             23.333333
# 243                             24.333333
# 244                             26.500000
# 245                             29.000000
# 246                             29.000000
# 247                             30.166667
# 248                             23.500000
# 249                             22.833333
# 250                             22.833333
# 251                             24.000000
# 252                             27.333333
#
#      total_rush_yards_allowed_last_6_avg_away  \
# 239                                119.166667
# 240                                 86.833333
# 241                                 76.666667
# 242                                105.166667
# 243                                 98.833333
# 244                                124.333333
# 245                                148.833333
# 246                                142.833333
# 247                                132.000000
# 248                                110.500000
# 249                                122.333333
# 250                                 88.833333
# 251                                 92.833333
# 252                                122.333333
#
#      rush_tds_allowed_last_6_avg_away  \
# 239                          1.166667
# 240                          0.500000
# 241                          0.500000
# 242                          1.000000
# 243                          1.333333
# 244                          0.333333
# 245                          0.833333
# 246                          1.333333
# 247                          1.000000
# 248                          0.666667
# 249                          0.666667
# 250                          1.166667
# 251                          0.666667
# 252                          0.500000
#
#      total_pass_attempts_allowed_last_6_avg_away  \
# 239                                    32.500000
# 240                                    36.833333
# 241                                    35.000000
# 242                                    35.500000
# 243                                    35.500000
# 244                                    36.833333
# 245                                    27.333333
# 246                                    30.833333
# 247                                    32.000000
# 248                                    37.833333
# 249                                    33.500000
# 250                                    33.500000
# 251                                    38.166667
# 252                                    31.833333
#
#      passing_yards_allowed_last_6_avg_away  \
# 239                             199.500000
# 240                             295.666667
# 241                             240.333333
# 242                             223.666667
# 243                             226.833333
# 244                             191.500000
# 245                             187.666667
# 246                             212.333333
# 247                             204.666667
# 248                             269.333333
# 249                             216.500000
# 250                             222.500000
# 251                             247.333333
# 252                             210.666667
#
#      completions_allowed_last_6_avg_away  pass_tds_allowed_last_6_avg_away  \
# 239                            18.166667                          1.166667
# 240                            26.500000                          2.333333
# 241                            23.166667                          1.333333
# 242                            22.666667                          1.166667
# 243                            24.000000                          1.666667
# 244                            23.166667                          1.333333
# 245                            17.166667                          2.000000
# 246                            20.166667                          1.666667
# 247                            20.833333                          1.500000
# 248                            25.000000                          2.166667
# 249                            20.666667                          1.666667
# 250                            21.500000                          1.500000
# 251                            22.333333                          1.000000
# 252                            20.500000                          1.166667
#
#      avg_cpoe_allowed_last_6_avg_away  sacks_last_6_avg_away  \
# 239                         -9.020295               4.000000
# 240                          6.425607               1.500000
# 241                          1.819170               4.000000
# 242                         -3.287161               1.666667
# 243                          2.429782               2.333333
# 244                         -3.450147               2.333333
# 245                         -2.407065               1.000000
# 246                         -0.477098               2.166667
# 247                         -0.598353               2.166667
# 248                          1.176965               2.000000
# 249                         -3.140345               2.500000
# 250                          3.636083               1.833333
# 251                         -4.294156               2.666667
# 252                         -2.448924               1.500000
#
#      fumbles_forced_last_6_avg_away  interceptions_last_6_avg_away  \
# 239                        0.666667                       0.833333
# 240                        0.166667                       0.666667
# 241                        0.833333                       0.833333
# 242                        0.833333                       1.000000
# 243                        0.500000                       0.666667
# 244                        1.000000                       1.000000
# 245                        0.000000                       0.666667
# 246                        0.333333                       0.333333
# 247                        0.500000                       0.333333
# 248                        0.666667                       0.333333
# 249                        0.166667                       1.166667
# 250                        0.166667                       0.166667
# 251                        1.333333                       0.666667
# 252                        0.333333                       0.500000
#
#      fumbles_recovered_last_6_avg_away  special_teams_epa_last_6_avg_away  \
# 239                           0.166667                          -0.566416
# 240                           0.166667                           3.701440
# 241                           0.166667                           1.251121
# 242                           0.333333                           1.105411
# 243                           0.000000                          -1.065036
# 244                           0.500000                          -5.490597
# 245                           0.000000                          -1.695173
# 246                           0.166667                          -3.052658
# 247                           0.166667                           0.025504
# 248                           0.500000                           0.462616
# 249                           0.166667                          -3.916560
# 250                           0.000000                           2.299223
# 251                           0.833333                          -1.894157
# 252                           0.333333                          -3.956281
#
#      passing_epa_def_last_6_avg_away  rushing_epa_def_last_6_avg_away
# 239                         3.621674                        -1.726747
# 240                       -11.328538                         1.703996
# 241                        -0.347728                         4.297906
# 242                         3.702753                        -0.963939
# 243                        -1.322339                         0.149113
# 244                         6.812504                        -2.668573
# 245                        -2.306805                        -4.471719
# 246                        -4.653238                        -1.915483
# 247                        -0.615174                        -0.029912
# 248                        -3.981759                        -0.606615
# 249                         2.790854                        -2.632813
# 250                        -6.006196                         1.911503
# 251                         2.911315                         7.087348
# 252                        -0.824746                        -0.610936

# %%
# Load moneyline predictor algorithm 

ml_algo = load('../saved_models/xgboost_iter_1_depth_4_estimators_125.joblib')

# %%
# Load point spread predictor algorithm 

hs_algo = load('../saved_models/elasticnet_hs_iter_1_alpha_0.25_ratio_1.joblib')
as_algo = load('../saved_models/elasticnet_as_iter_1_alpha_1_ratio_0.1.joblib')

# %%
# Load over under predictor algorithm 

ou_algo = load('../saved_models/elasticnet_ts_iter_1_alpha_1_ratio_0.joblib')

# %%
# Function for getting predictions

def get_predictions(trained_model, testing_set, target = 'game_winner', predict_home = 'True'):
    
    test = testing_set.copy()
    test.drop(columns = ['season', 'week', 'home', 'away', 'home_full_name', 'away_full_name',
                         'season_home', 'week_home', 'season_away', 'week_away', 
                         'team_full_name_home', 'team_full_name_away', 'qb_home', 'qb_away', 'Unnamed: 0'], 
                          inplace=True)
    preds = testing_set.copy()
    preds = preds[['season', 'week', 'home_full_name', 'away_full_name']]
        
    if target == 'game_winner':
    
        pred = trained_model.predict(test)
        
        pred_prob = trained_model.predict_proba(test)
        
        preds['home_win_pred'] = pred
        preds[['away_win_prob', 'home_win_prob']] = pred_prob
        
        return preds
        
    elif target == 'point_spread':
        pred = trained_model.predict(test)
        
        if predict_home:
            preds['home_score_pred'] = pred
            
        else:
            preds['away_score_pred'] = pred
        
        return preds
    
    else:
        pred = trained_model.predict(test)
        
        preds['total_score_pred'] = pred
        
        return preds

# %%
# Get predictions

ml_preds = get_predictions(ml_algo, predictive_stats, target='game_winner')
hs_preds = get_predictions(hs_algo, predictive_stats, target='point_spread')
as_preds = get_predictions(as_algo, predictive_stats, target='point_spread', predict_home = False)
ts_preds = get_predictions(ou_algo, predictive_stats, target='total_score')

combined_predictions = ml_preds.merge(hs_preds).merge(as_preds).merge(ts_preds)
combined_predictions = combined_predictions[['season', 'week', 'home_full_name', 'away_full_name', 
                                            'home_win_pred', 'home_win_prob', 'away_win_prob', 
                                            'home_score_pred', 'away_score_pred', 'total_score_pred']]
combined_predictions
# Out:
#     season  week            home_full_name        away_full_name  \
# 0     2022     1          Los Angeles Rams         Buffalo Bills
# 1     2022     1             New York Jets      Baltimore Ravens
# 2     2022     1             Chicago Bears   San Francisco 49ers
# 3     2022     1            Houston Texans    Indianapolis Colts
# 4     2022     1             Detroit Lions   Philadelphia Eagles
# 5     2022     1         Carolina Panthers      Cleveland Browns
# 6     2022     1            Miami Dolphins  New England Patriots
# 7     2022     1  Washington Football Team  Jacksonville Jaguars
# 8     2022     1          Tennessee Titans       New York Giants
# 9     2022     1         Arizona Cardinals    Kansas City Chiefs
# 10    2022     1         Minnesota Vikings     Green Bay Packers
# 11    2022     1      Los Angeles Chargers     Las Vegas Raiders
# 12    2022     1            Dallas Cowboys  Tampa Bay Buccaneers
# 13    2022     1          Seattle Seahawks        Denver Broncos
#
#     home_win_pred  home_win_prob  away_win_prob  home_score_pred  \
# 0               0       0.324052       0.675948        20.429601
# 1               0       0.363587       0.636413        19.023155
# 2               1       0.507643       0.492357        20.692645
# 3               0       0.363027       0.636973        20.456048
# 4               0       0.483381       0.516619        19.881645
# 5               1       0.589871       0.410129        19.727278
# 6               1       0.611502       0.388498        22.097193
# 7               1       0.788429       0.211571        25.648667
# 8               1       0.810063       0.189937        21.669875
# 9               0       0.348749       0.651251        22.677775
# 10              0       0.335873       0.664127        22.897941
# 11              1       0.691996       0.308004        28.254481
# 12              1       0.747081       0.252919        27.586916
# 13              0       0.301759       0.698241        21.421038
#
#     away_score_pred  total_score_pred
# 0         25.279852         45.223804
# 1         26.173709         45.673831
# 2         20.684892         41.176389
# 3         24.657620         45.424629
# 4         22.732696         42.908845
# 5         22.227076         42.325054
# 6         17.036484         38.745552
# 7         17.686919         43.230369
# 8         16.064640         37.858003
# 9         28.658534         51.715226
# 10        24.707565         47.452350
# 11        22.219303         51.669675
# 12        23.929618         51.859906
# 13        19.613444         40.879043

# %%
# Add betting data

final_df = combined_predictions.merge(current_week_odds)
final_df.drop(columns = ['Unnamed: 0', 'away', 'home', 'home_qb', 'away_qb'], inplace=True)
final_df = final_df[['season', 'week', 'home_full_name', 'away_full_name', 
                                            'home_win_pred', 'home_win_prob', 'away_win_prob', 
                                            'home_score_pred', 'away_score_pred', 'total_score_pred',
                    'home_moneyline', 'away_moneyline', 'home_spread', 'away_spread', 'over_under']]
# final_df

# %%
# Add columns for Vegas moneyline implied win probabilities 

def get_implied_probability(game, open_line=True, home=True):
    
    if home:
        home_or_away = 'home'
    else:
        home_or_away = 'away'
        
    betting_column = '{}_moneyline'.format(home_or_away)
    
    ml_odds = game[betting_column]
    
    if ml_odds > 0:
        return (100/(ml_odds + 100))
    else:
        return (-ml_odds/(-ml_odds + 100))

final_df['implied_prob_home'] = final_df.apply(lambda x: get_implied_probability(x, home=True), axis=1)
final_df['implied_prob_away'] = final_df.apply(lambda x: get_implied_probability(x, home=False), axis=1)

# %%
# Add column to identify best algorithmic advantage
# Add column to calculate betting proportion amount

def get_prob_advantage_algo(game):
    advantage_home = game['home_win_prob'] - game['implied_prob_home']
    advantage_away = game['away_win_prob'] - game['implied_prob_away']
    
    if advantage_home > advantage_away:
        return advantage_home, 'home'
    else:
        return advantage_away, 'away'
    
def get_bet_proportional_algo(game):
    
    bet_weight = 0
    
    if .03 <= game.best_prob_advantage < .05:
        bet_weight = 1
    elif .05 <= game.best_prob_advantage < .1:
        bet_weight = 2
    elif .1<= game.best_prob_advantage < .15:
        bet_weight = 3
    elif .15 <= game.best_prob_advantage < .2:
        bet_weight = 4
    elif game.best_prob_advantage >= .2 :
        bet_weight = 5
        
    return bet_weight
    
final_df = final_df.join(pd.DataFrame(final_df.apply(lambda x: get_prob_advantage_algo(x), axis=1).tolist(), columns=['best_prob_advantage', 'advantage_team']))
final_df['moneyline_bet_proportion'] = final_df.apply(lambda x: get_bet_proportional_algo(x), axis=1)

# %%
# Get spread differences 

final_df['home_spread_pred'] = final_df.apply(lambda x: x.away_score_pred - x.home_score_pred, axis=1)
final_df['away_spread_pred'] = final_df.apply(lambda x: x.home_score_pred - x.away_score_pred, axis=1)
final_df['home_line_diff'] = final_df.apply(lambda x: x.home_spread - x.home_spread_pred, axis=1)
final_df['away_line_diff'] = final_df.apply(lambda x: x.away_spread - x.away_spread_pred, axis=1)
final_df['total_score_diff'] = final_df.apply(lambda x: x.total_score_pred - x.over_under, axis=1)

# %%
# Get spread advantages, over/under advantages

def get_best_spread_advantage(game):
    
    if game.home_line_diff > game.away_line_diff:
        return game.home_line_diff, 'home'
    else:
        return game.away_line_diff, 'away'
    
def get_best_ou_advantage(game):
    
    if game.total_score_diff > 0:
        return 'over'
    else:
        return 'under'
    
def get_return_proportional_spread(game):
    
    bet_weight = 0
    
    if 3 <= game.best_spread_advantage < 4:
        bet_weight = 1
    elif 4 <= game.best_spread_advantage < 5:
        bet_weight = 2
    elif 5 <= game.best_spread_advantage < 6:
        bet_weight = 3
    elif 6 <= game.best_spread_advantage < 7:
        bet_weight = 4
    elif game.best_spread_advantage >= 7 :
        bet_weight = 5
        
    return bet_weight
    
def get_return_proportional_ou(game):
    
    bet_weight = 0
    
    if 1 <= abs(game.total_score_diff) < 2:
        bet_weight = 1
    elif 2 <= abs(game.total_score_diff) < 3:
        bet_weight = 2
    elif 3 <= abs(game.total_score_diff) < 4:
        bet_weight = 3
    elif 4 <= abs(game.total_score_diff) < 5:
        bet_weight = 4
    elif abs(game.total_score_diff) >= 5 :
        bet_weight = 5
        
    return bet_weight

def get_team_to_bet_on(game):
    
    if game.spread_bet_proportion <= 0:
        return game.advantage_team
    else:
        return game.spread_advantage_team

final_df[['best_spread_advantage', 'spread_advantage_team']] = final_df.apply(lambda x: get_best_spread_advantage(x), axis=1, result_type='expand')
final_df['spread_bet_proportion'] = final_df.apply(lambda x: get_return_proportional_spread(x), axis=1)
final_df['ou_advantage'] = final_df.apply(lambda x: get_best_ou_advantage(x), axis=1)
final_df['ou_bet_proportion'] = final_df.apply(lambda x: get_return_proportional_ou(x), axis=1)

# %%
final_df
# Out:
#     season  week            home_full_name        away_full_name  \
# 0     2022     1          Los Angeles Rams         Buffalo Bills
# 1     2022     1             New York Jets      Baltimore Ravens
# 2     2022     1             Chicago Bears   San Francisco 49ers
# 3     2022     1            Houston Texans    Indianapolis Colts
# 4     2022     1             Detroit Lions   Philadelphia Eagles
# 5     2022     1         Carolina Panthers      Cleveland Browns
# 6     2022     1            Miami Dolphins  New England Patriots
# 7     2022     1  Washington Football Team  Jacksonville Jaguars
# 8     2022     1          Tennessee Titans       New York Giants
# 9     2022     1         Arizona Cardinals    Kansas City Chiefs
# 10    2022     1         Minnesota Vikings     Green Bay Packers
# 11    2022     1      Los Angeles Chargers     Las Vegas Raiders
# 12    2022     1            Dallas Cowboys  Tampa Bay Buccaneers
# 13    2022     1          Seattle Seahawks        Denver Broncos
#
#     home_win_pred  home_win_prob  away_win_prob  home_score_pred  \
# 0               0       0.324052       0.675948        20.429601
# 1               0       0.363587       0.636413        19.023155
# 2               1       0.507643       0.492357        20.692645
# 3               0       0.363027       0.636973        20.456048
# 4               0       0.483381       0.516619        19.881645
# 5               1       0.589871       0.410129        19.727278
# 6               1       0.611502       0.388498        22.097193
# 7               1       0.788429       0.211571        25.648667
# 8               1       0.810063       0.189937        21.669875
# 9               0       0.348749       0.651251        22.677775
# 10              0       0.335873       0.664127        22.897941
# 11              1       0.691996       0.308004        28.254481
# 12              1       0.747081       0.252919        27.586916
# 13              0       0.301759       0.698241        21.421038
#
#     away_score_pred  total_score_pred  home_moneyline  away_moneyline  \
# 0         25.279852         45.223804             115            -135
# 1         26.173709         45.673831             245            -295
# 2         20.684892         41.176389             245            -295
# 3         24.657620         45.424629             320            -390
# 4         22.732696         42.908845             165            -195
# 5         22.227076         42.325054            -140             120
# 6         17.036484         38.745552            -155             135
# 7         17.686919         43.230369            -165             140
# 8         16.064640         37.858003            -250             210
# 9         28.658534         51.715226             175            -205
# 10        24.707565         47.452350             100            -120
# 11        22.219303         51.669675            -180             155
# 12        23.929618         51.859906             100            -120
# 13        19.613444         40.879043             220            -260
#
#     home_spread  away_spread  over_under  implied_prob_home  \
# 0           2.5         -2.5        52.5           0.465116
# 1           7.0         -7.0        44.5           0.289855
# 2           7.0         -7.0        41.5           0.289855
# 3           8.0         -8.0        46.0           0.238095
# 4           4.0         -4.0        48.5           0.377358
# 5          -2.5          2.5        41.5           0.583333
# 6          -3.0          3.0        46.5           0.607843
# 7          -3.0          3.0        44.0           0.622642
# 8          -5.5          5.5        43.5           0.714286
# 9           4.5         -4.5        53.5           0.363636
# 10          1.0         -1.0        48.0           0.500000
# 11         -3.5          3.5        52.5           0.642857
# 12          1.5         -1.5        50.0           0.500000
# 13          6.5         -6.5        43.0           0.312500
#
#     implied_prob_away  best_prob_advantage advantage_team  \
# 0            0.574468             0.101480           away
# 1            0.746835             0.073732           home
# 2            0.746835             0.217788           home
# 3            0.795918             0.124932           home
# 4            0.661017             0.106022           home
# 5            0.454545             0.006537           home
# 6            0.425532             0.003659           home
# 7            0.416667             0.165787           home
# 8            0.322581             0.095778           home
# 9            0.672131            -0.014887           home
# 10           0.545455             0.118673           away
# 11           0.392157             0.049139           home
# 12           0.545455             0.247081           home
# 13           0.722222            -0.010741           home
#
#     moneyline_bet_proportion  home_spread_pred  away_spread_pred  \
# 0                          3          4.850252         -4.850252
# 1                          2          7.150554         -7.150554
# 2                          5         -0.007753          0.007753
# 3                          3          4.201572         -4.201572
# 4                          3          2.851052         -2.851052
# 5                          0          2.499798         -2.499798
# 6                          0         -5.060710          5.060710
# 7                          4         -7.961749          7.961749
# 8                          2         -5.605235          5.605235
# 9                          0          5.980759         -5.980759
# 10                         3          1.809623         -1.809623
# 11                         1         -6.035177          6.035177
# 12                         5         -3.657298          3.657298
# 13                         0         -1.807594          1.807594
#
#     home_line_diff  away_line_diff  total_score_diff  best_spread_advantage  \
# 0        -2.350252        2.350252         -7.276196               2.350252
# 1        -0.150554        0.150554          1.173831               0.150554
# 2         7.007753       -7.007753         -0.323611               7.007753
# 3         3.798428       -3.798428         -0.575371               3.798428
# 4         1.148948       -1.148948         -5.591155               1.148948
# 5        -4.999798        4.999798          0.825054               4.999798
# 6         2.060710       -2.060710         -7.754448               2.060710
# 7         4.961749       -4.961749         -0.769631               4.961749
# 8         0.105235       -0.105235         -5.641997               0.105235
# 9        -1.480759        1.480759         -1.784774               1.480759
# 10       -0.809623        0.809623         -0.547650               0.809623
# 11        2.535177       -2.535177         -0.830325               2.535177
# 12        5.157298       -5.157298          1.859906               5.157298
# 13        8.307594       -8.307594         -2.120957               8.307594
#
#    spread_advantage_team  spread_bet_proportion ou_advantage  \
# 0                   away                      0        under
# 1                   away                      0         over
# 2                   home                      5        under
# 3                   home                      1        under
# 4                   home                      0        under
# 5                   away                      2         over
# 6                   home                      0        under
# 7                   home                      2        under
# 8                   home                      0        under
# 9                   away                      0        under
# 10                  away                      0        under
# 11                  home                      0        under
# 12                  home                      3         over
# 13                  home                      5        under
#
#     ou_bet_proportion
# 0                   5
# 1                   1
# 2                   0
# 3                   0
# 4                   5
# 5                   0
# 6                   5
# 7                   0
# 8                   5
# 9                   1
# 10                  0
# 11                  0
# 12                  1
# 13                  2

# %%
# Get wager amounts

base_wager = 50

gambling_df = final_df.copy()
gambling_df['ou_wager'] = gambling_df.ou_bet_proportion * base_wager
gambling_df['moneyline_wager'] = gambling_df.moneyline_bet_proportion * base_wager
gambling_df['spread_wager'] = gambling_df.spread_bet_proportion * base_wager
gambling_df = gambling_df[~((((gambling_df.spread_advantage_team == 'away') & (gambling_df.advantage_team == 'home')) 
                         | ((gambling_df.spread_advantage_team == 'home') & (gambling_df.advantage_team == 'away')))
                         & ((gambling_df.moneyline_wager>0) & (gambling_df.spread_wager>0)))]
gambling_df['wager_team'] = gambling_df.apply(lambda x: get_team_to_bet_on(x), axis=1)
gambling_df['total_wager'] = gambling_df.ou_wager + gambling_df.moneyline_wager + gambling_df.spread_wager
gambling_df
# Out:
#     season  week            home_full_name        away_full_name  \
# 0     2022     1          Los Angeles Rams         Buffalo Bills
# 1     2022     1             New York Jets      Baltimore Ravens
# 2     2022     1             Chicago Bears   San Francisco 49ers
# 3     2022     1            Houston Texans    Indianapolis Colts
# 4     2022     1             Detroit Lions   Philadelphia Eagles
# 5     2022     1         Carolina Panthers      Cleveland Browns
# 6     2022     1            Miami Dolphins  New England Patriots
# 7     2022     1  Washington Football Team  Jacksonville Jaguars
# 8     2022     1          Tennessee Titans       New York Giants
# 9     2022     1         Arizona Cardinals    Kansas City Chiefs
# 10    2022     1         Minnesota Vikings     Green Bay Packers
# 11    2022     1      Los Angeles Chargers     Las Vegas Raiders
# 12    2022     1            Dallas Cowboys  Tampa Bay Buccaneers
# 13    2022     1          Seattle Seahawks        Denver Broncos
#
#     home_win_pred  home_win_prob  away_win_prob  home_score_pred  \
# 0               0       0.324052       0.675948        20.429601
# 1               0       0.363587       0.636413        19.023155
# 2               1       0.507643       0.492357        20.692645
# 3               0       0.363027       0.636973        20.456048
# 4               0       0.483381       0.516619        19.881645
# 5               1       0.589871       0.410129        19.727278
# 6               1       0.611502       0.388498        22.097193
# 7               1       0.788429       0.211571        25.648667
# 8               1       0.810063       0.189937        21.669875
# 9               0       0.348749       0.651251        22.677775
# 10              0       0.335873       0.664127        22.897941
# 11              1       0.691996       0.308004        28.254481
# 12              1       0.747081       0.252919        27.586916
# 13              0       0.301759       0.698241        21.421038
#
#     away_score_pred  total_score_pred  home_moneyline  away_moneyline  \
# 0         25.279852         45.223804             115            -135
# 1         26.173709         45.673831             245            -295
# 2         20.684892         41.176389             245            -295
# 3         24.657620         45.424629             320            -390
# 4         22.732696         42.908845             165            -195
# 5         22.227076         42.325054            -140             120
# 6         17.036484         38.745552            -155             135
# 7         17.686919         43.230369            -165             140
# 8         16.064640         37.858003            -250             210
# 9         28.658534         51.715226             175            -205
# 10        24.707565         47.452350             100            -120
# 11        22.219303         51.669675            -180             155
# 12        23.929618         51.859906             100            -120
# 13        19.613444         40.879043             220            -260
#
#     home_spread  away_spread  over_under  implied_prob_home  \
# 0           2.5         -2.5        52.5           0.465116
# 1           7.0         -7.0        44.5           0.289855
# 2           7.0         -7.0        41.5           0.289855
# 3           8.0         -8.0        46.0           0.238095
# 4           4.0         -4.0        48.5           0.377358
# 5          -2.5          2.5        41.5           0.583333
# 6          -3.0          3.0        46.5           0.607843
# 7          -3.0          3.0        44.0           0.622642
# 8          -5.5          5.5        43.5           0.714286
# 9           4.5         -4.5        53.5           0.363636
# 10          1.0         -1.0        48.0           0.500000
# 11         -3.5          3.5        52.5           0.642857
# 12          1.5         -1.5        50.0           0.500000
# 13          6.5         -6.5        43.0           0.312500
#
#     implied_prob_away  best_prob_advantage advantage_team  \
# 0            0.574468             0.101480           away
# 1            0.746835             0.073732           home
# 2            0.746835             0.217788           home
# 3            0.795918             0.124932           home
# 4            0.661017             0.106022           home
# 5            0.454545             0.006537           home
# 6            0.425532             0.003659           home
# 7            0.416667             0.165787           home
# 8            0.322581             0.095778           home
# 9            0.672131            -0.014887           home
# 10           0.545455             0.118673           away
# 11           0.392157             0.049139           home
# 12           0.545455             0.247081           home
# 13           0.722222            -0.010741           home
#
#     moneyline_bet_proportion  home_spread_pred  away_spread_pred  \
# 0                          3          4.850252         -4.850252
# 1                          2          7.150554         -7.150554
# 2                          5         -0.007753          0.007753
# 3                          3          4.201572         -4.201572
# 4                          3          2.851052         -2.851052
# 5                          0          2.499798         -2.499798
# 6                          0         -5.060710          5.060710
# 7                          4         -7.961749          7.961749
# 8                          2         -5.605235          5.605235
# 9                          0          5.980759         -5.980759
# 10                         3          1.809623         -1.809623
# 11                         1         -6.035177          6.035177
# 12                         5         -3.657298          3.657298
# 13                         0         -1.807594          1.807594
#
#     home_line_diff  away_line_diff  total_score_diff  best_spread_advantage  \
# 0        -2.350252        2.350252         -7.276196               2.350252
# 1        -0.150554        0.150554          1.173831               0.150554
# 2         7.007753       -7.007753         -0.323611               7.007753
# 3         3.798428       -3.798428         -0.575371               3.798428
# 4         1.148948       -1.148948         -5.591155               1.148948
# 5        -4.999798        4.999798          0.825054               4.999798
# 6         2.060710       -2.060710         -7.754448               2.060710
# 7         4.961749       -4.961749         -0.769631               4.961749
# 8         0.105235       -0.105235         -5.641997               0.105235
# 9        -1.480759        1.480759         -1.784774               1.480759
# 10       -0.809623        0.809623         -0.547650               0.809623
# 11        2.535177       -2.535177         -0.830325               2.535177
# 12        5.157298       -5.157298          1.859906               5.157298
# 13        8.307594       -8.307594         -2.120957               8.307594
#
#    spread_advantage_team  spread_bet_proportion ou_advantage  \
# 0                   away                      0        under
# 1                   away                      0         over
# 2                   home                      5        under
# 3                   home                      1        under
# 4                   home                      0        under
# 5                   away                      2         over
# 6                   home                      0        under
# 7                   home                      2        under
# 8                   home                      0        under
# 9                   away                      0        under
# 10                  away                      0        under
# 11                  home                      0        under
# 12                  home                      3         over
# 13                  home                      5        under
#
#     ou_bet_proportion  ou_wager  moneyline_wager  spread_wager wager_team  \
# 0                   5       250              150             0       away
# 1                   1        50              100             0       home
# 2                   0         0              250           250       home
# 3                   0         0              150            50       home
# 4                   5       250              150             0       home
# 5                   0         0                0           100       away
# 6                   5       250                0             0       home
# 7                   0         0              200           100       home
# 8                   5       250              100             0       home
# 9                   1        50                0             0       home
# 10                  0         0              150             0       away
# 11                  0         0               50             0       home
# 12                  1        50              250           150       home
# 13                  2       100                0           250       home
#
#     total_wager
# 0           400
# 1           150
# 2           500
# 3           200
# 4           400
# 5           100
# 6           250
# 7           300
# 8           350
# 9            50
# 10          150
# 11           50
# 12          450
# 13          350

# %%
# Total wager amount for the week

print('Week Total Wager Amount: {}'.format(sum(gambling_df.total_wager)))
# Out:
# Week Total Wager Amount: 3700

# %%
# Analyze results

# %%
# Save predictions and bets
