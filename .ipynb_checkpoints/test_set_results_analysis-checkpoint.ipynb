# %%
# Import packages

import pandas as pd 
import numpy as np 
import os
from bs4 import BeautifulSoup
import time
import requests
import nfl_data_py as nfl
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import random
import scipy

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

import pickle
from joblib import dump, load

import warnings

# Set certain settings for the notebook
pd.set_option("display.max_columns", None)

warnings.filterwarnings("ignore")

# %%
# Read in data 

point_spread_results = pd.read_csv('../data/spreads_test_set_results.csv')
moneyline_results = pd.read_csv('../data/moneyline_test_set_results.csv')
point_spread_results
# Out:
#      Unnamed: 0  Unnamed: 0_x        Date                 Home Team  \
# 0             0             0  2022-01-17          Los Angeles Rams
# 1             1             1  2022-01-16        Kansas City Chiefs
# 2             2             2  2022-01-16            Dallas Cowboys
# 3             3             3  2022-01-16      Tampa Bay Buccaneers
# 4             4             4  2022-01-15             Buffalo Bills
# ..          ...           ...         ...                       ...
# 259         259           271  2021-09-12             Detroit Lions
# 260         260           273  2021-09-12        Indianapolis Colts
# 261         261           274  2021-09-12          Tennessee Titans
# 262         262           275  2021-09-12  Washington Football Team
# 263         263           276  2021-09-09      Tampa Bay Buccaneers
#
#                 Away Team  Home Score  Away Score  Overtime?  Playoff Game?  \
# 0       Arizona Cardinals          34          11      False           True
# 1     Pittsburgh Steelers          42          21      False           True
# 2     San Francisco 49ers          17          23      False           True
# 3     Philadelphia Eagles          31          15      False           True
# 4    New England Patriots          47          17      False           True
# ..                    ...         ...         ...        ...            ...
# 259   San Francisco 49ers          33          41      False          False
# 260      Seattle Seahawks          16          28      False          False
# 261     Arizona Cardinals          13          38      False          False
# 262  Los Angeles Chargers          16          20      False          False
# 263        Dallas Cowboys          31          29      False          False
#
#      Neutral Venue?  Home Line Open  Home Line Close  Away Line Open  \
# 0             False            -4.5             -3.5             4.5
# 1             False           -13.5            -12.5            13.5
# 2             False            -3.0             -3.5             3.0
# 3             False            -8.5             -7.0             8.5
# 4             False            -4.5             -4.5             4.5
# ..              ...             ...              ...             ...
# 259           False             7.5              7.5            -7.5
# 260           False            -3.0              2.5             3.0
# 261           False            -3.0             -3.0             3.0
# 262           False             1.0              1.0            -1.0
# 263           False            -6.5             -7.5             6.5
#
#      Away Line Close  Total Score Open  Total Score Close  Home Odds ML Open  \
# 0                3.5              50.5               49.0             -200.0
# 1               12.5              46.5               47.0             -714.0
# 2                3.5              50.5               51.0             -161.0
# 3                7.0              49.0               47.0             -400.0
# 4                4.5              43.5               43.0             -213.0
# ..               ...               ...                ...                ...
# 259             -7.5              46.0               46.0              325.0
# 260             -2.5              52.0               48.5             -147.0
# 261              3.0              51.0               51.5             -141.0
# 262             -1.0              44.5               44.5              105.0
# 263              7.5              51.5               51.5             -270.0
#
#      Home Odds ML Close  Away Odds ML Open  Away Odds ML Close  \
# 0                -172.0              170.0               150.0
# 1                -833.0              500.0               550.0
# 2                -185.0              140.0               165.0
# 3                -370.0              320.0               280.0
# 4                -222.0              175.0               180.0
# ..                  ...                ...                 ...
# 259               290.0             -435.0              -370.0
# 260               130.0              125.0              -152.0
# 261              -156.0              120.0               135.0
# 262               100.0             -125.0              -120.0
# 263              -357.0              220.0               275.0
#
#      Home Line Odds ML Open  Home Line Odds ML Close  Away Line Odds ML Open  \
# 0                    -111.0                    100.0                  -111.0
# 1                    -111.0                   -111.0                  -111.0
# 2                    -111.0                   -111.0                  -111.0
# 3                    -111.0                   -116.0                  -111.0
# 4                    -111.0                   -111.0                  -111.0
# ..                      ...                      ...                     ...
# 259                  -111.0                   -116.0                  -111.0
# 260                   105.0                    100.0                  -125.0
# 261                   100.0                   -105.0                  -120.0
# 262                  -111.0                   -111.0                  -111.0
# 263                  -111.0                   -111.0                  -111.0
#
#      Away Line Odds ML Close  Total Score Over ML Open  \
# 0                     -120.0                    -111.0
# 1                     -111.0                    -111.0
# 2                     -111.0                    -111.0
# 3                     -105.0                    -111.0
# 4                     -111.0                    -111.0
# ..                       ...                       ...
# 259                   -105.0                    -111.0
# 260                   -120.0                    -111.0
# 261                   -116.0                    -111.0
# 262                   -111.0                    -111.0
# 263                   -111.0                    -111.0
#
#      Total Score Over ML Close  Total Score Under ML Open  \
# 0                       -111.0                     -111.0
# 1                       -111.0                     -111.0
# 2                       -111.0                     -111.0
# 3                       -111.0                     -111.0
# 4                       -111.0                     -111.0
# ..                         ...                        ...
# 259                     -111.0                     -111.0
# 260                     -111.0                     -111.0
# 261                     -111.0                     -111.0
# 262                     -111.0                     -111.0
# 263                     -111.0                     -111.0
#
#      Total Score Under ML Close  Total Score Open Over/Under Result  \
# 0                        -111.0           45                  Under
# 1                        -111.0           63                   Over
# 2                        -111.0           40                  Under
# 3                        -111.0           46                  Under
# 4                        -111.0           64                   Over
# ..                          ...          ...                    ...
# 259                      -111.0           74                   Over
# 260                      -111.0           44                  Under
# 261                      -111.0           51                   Push
# 262                      -111.0           36                  Under
# 263                      -111.0           60                   Over
#
#     Closing Over/Under Result  Home Score Actual Line  Away Score Actual Line  \
# 0                       Under                     -23                      23
# 1                        Over                     -21                      21
# 2                       Under                       6                      -6
# 3                       Under                     -16                      16
# 4                        Over                     -30                      30
# ..                        ...                     ...                     ...
# 259                      Over                       8                      -8
# 260                     Under                      12                     -12
# 261                     Under                      25                     -25
# 262                     Under                       4                      -4
# 263                      Over                      -2                       2
#
#     Opening Winner Closing Winner Opening Winner Specific  \
# 0         Favorite       Favorite           Home Favorite
# 1         Favorite       Favorite           Home Favorite
# 2         Underdog       Underdog           Away Underdog
# 3         Favorite       Favorite           Home Favorite
# 4         Favorite       Favorite           Home Favorite
# ..             ...            ...                     ...
# 259       Favorite       Favorite           Away Favorite
# 260       Underdog       Favorite           Away Underdog
# 261       Underdog       Underdog           Away Underdog
# 262       Favorite       Favorite           Away Favorite
# 263       Favorite       Favorite           Home Favorite
#
#     Closing Winner Specific Winner HA Line Open Cover Line Close Cover  \
# 0             Home Favorite      Home        Favorite         Favorite
# 1             Home Favorite      Home        Favorite         Favorite
# 2             Away Underdog      Away        Underdog         Underdog
# 3             Home Favorite      Home        Favorite         Favorite
# 4             Home Favorite      Home        Favorite         Favorite
# ..                      ...       ...             ...              ...
# 259           Away Favorite      Away        Favorite         Favorite
# 260           Away Favorite      Away        Underdog         Favorite
# 261           Away Underdog      Away        Underdog         Underdog
# 262           Away Favorite      Away        Favorite         Favorite
# 263           Home Favorite      Home        Underdog         Underdog
#
#     Line Open Cover HA Line Close Cover HA  Home ML Bet Return  \
# 0                 Home                Home               50.00
# 1                 Home                Home               14.01
# 2                 Away                Away             -100.00
# 3                 Home                Home               25.00
# 4                 Home                Home               46.95
# ..                 ...                 ...                 ...
# 259               Away                Away             -100.00
# 260               Away                Away             -100.00
# 261               Away                Away             -100.00
# 262               Away                Away             -100.00
# 263               Away                Away               37.04
#
#      Away ML Bet Return  Home Spread Bet Return  Away Spread Bet Return  \
# 0               -100.00                   90.09                 -100.00
# 1               -100.00                   90.09                 -100.00
# 2                140.00                 -100.00                   90.09
# 3               -100.00                   90.09                 -100.00
# 4               -100.00                   90.09                 -100.00
# ..                  ...                     ...                     ...
# 259               22.99                 -100.00                   90.09
# 260              125.00                 -100.00                   80.00
# 261              120.00                 -100.00                   83.33
# 262               80.00                 -100.00                   90.09
# 263             -100.00                 -100.00                   90.09
#
#      Favorite ML Bet Return  Underdog ML Bet Return  \
# 0                     50.00                  -100.0
# 1                     14.01                  -100.0
# 2                   -100.00                   140.0
# 3                     25.00                  -100.0
# 4                     46.95                  -100.0
# ..                      ...                     ...
# 259                   22.99                  -100.0
# 260                 -100.00                   125.0
# 261                 -100.00                   120.0
# 262                   80.00                  -100.0
# 263                   37.04                  -100.0
#
#      Favorite Spread Bet Return  Underdog Spread Bet Return  \
# 0                         90.09                     -100.00
# 1                         90.09                     -100.00
# 2                       -100.00                       90.09
# 3                         90.09                     -100.00
# 4                         90.09                     -100.00
# ..                          ...                         ...
# 259                       90.09                     -100.00
# 260                     -100.00                       80.00
# 261                     -100.00                       83.33
# 262                       90.09                     -100.00
# 263                     -100.00                       90.09
#
#      implied_prob_home_open  implied_prob_away_open  implied_prob_home_close  \
# 0                  0.666667                0.370370                 0.632353
# 1                  0.877150                0.166667                 0.892819
# 2                  0.616858                0.416667                 0.649123
# 3                  0.800000                0.238095                 0.787234
# 4                  0.680511                0.363636                 0.689441
# ..                      ...                     ...                      ...
# 259                0.235294                0.813084                 0.256410
# 260                0.595142                0.444444                 0.434783
# 261                0.585062                0.454545                 0.609375
# 262                0.487805                0.555556                 0.500000
# 263                0.729730                0.312500                 0.781182
#
#      implied_prob_away_close  total_implied_prob_open  \
# 0                   0.400000                 1.037037
# 1                   0.153846                 1.043817
# 2                   0.377358                 1.033525
# 3                   0.263158                 1.038095
# 4                   0.357143                 1.044148
# ..                       ...                      ...
# 259                 0.787234                 1.048378
# 260                 0.603175                 1.039586
# 261                 0.425532                 1.039608
# 262                 0.545455                 1.043360
# 263                 0.266667                 1.042230
#
#      total_implied_prob_close  week  season  Unnamed: 0_y  \
# 0                    1.032353    19    2021             0
# 1                    1.046665    19    2021             1
# 2                    1.026481    19    2021             2
# 3                    1.050392    19    2021             3
# 4                    1.046584    19    2021             4
# ..                        ...   ...     ...           ...
# 259                  1.043644     1    2021           259
# 260                  1.037957     1    2021           260
# 261                  1.034907     1    2021           261
# 262                  1.045455     1    2021           262
# 263                  1.047848     1    2021           263
#
#                        home_x                away_x  home_score  away_score  \
# 0            Los Angeles Rams     Arizona Cardinals          34          11
# 1          Kansas City Chiefs   Pittsburgh Steelers          42          21
# 2              Dallas Cowboys   San Francisco 49ers          17          23
# 3        Tampa Bay Buccaneers   Philadelphia Eagles          31          15
# 4               Buffalo Bills  New England Patriots          47          17
# ..                        ...                   ...         ...         ...
# 259             Detroit Lions   San Francisco 49ers          33          41
# 260        Indianapolis Colts      Seattle Seahawks          16          28
# 261          Tennessee Titans     Arizona Cardinals          13          38
# 262  Washington Football Team  Los Angeles Chargers          16          20
# 263      Tampa Bay Buccaneers        Dallas Cowboys          31          29
#
#      total_score winner  home_win  home_score_pred  away_score_pred  \
# 0             45   Home         1        25.336177        22.903473
# 1             63   Home         1        29.034506        20.149831
# 2             40   Away         0        29.204910        20.528647
# 3             46   Home         1        24.252277        21.560780
# 4             64   Home         1        27.971527        18.806254
# ..           ...    ...       ...              ...              ...
# 259           74   Away         0        22.345221        24.252518
# 260           44   Away         0        15.851038        22.663891
# 261           51   Away         0        23.469574        24.807407
# 262           36   Away         0        27.242985        20.840780
# 263           60   Home         1        27.038755        26.055734
#
#      total_score_pred  home_spread_algo  away_spread_algo  home_spread_elo  \
# 0           48.668136         -2.432703          2.432703        -3.300755
# 1           49.473663         -8.884675          8.884675        -6.687744
# 2           49.783347         -8.676262          8.676262        -1.883657
# 3           46.149105         -2.691497          2.691497        -5.634525
# 4           46.979024         -9.165272          9.165272        -2.775093
# ..                ...               ...               ...              ...
# 259         47.006921          1.907297         -1.907297         7.140008
# 260         38.963053          6.812853         -6.812853         1.023249
# 261         47.488239          1.337834         -1.337834        -2.062961
# 262         48.333764         -6.402205          6.402205         1.124565
# 263         52.943710         -0.983021          0.983021        -5.152917
#
#      away_spread_elo  over_bet_return  under_bet_return  home_line_diff_algo  \
# 0           3.300755          -100.00             90.09            -2.067297
# 1           6.687744            90.09           -100.00            -4.615325
# 2           1.883657          -100.00             90.09             5.676262
# 3           5.634525          -100.00             90.09            -5.808503
# 4           2.775093            90.09           -100.00             4.665272
# ..               ...              ...               ...                  ...
# 259        -7.140008            90.09           -100.00             5.592703
# 260        -1.023249          -100.00             90.09            -9.812853
# 261         2.062961             0.00              0.00            -4.337834
# 262        -1.124565          -100.00             90.09             7.402205
# 263         5.152917            90.09           -100.00            -5.516979
#
#      away_line_diff_algo  home_line_diff_elo  away_line_diff_elo  \
# 0               2.067297           -1.199245            1.199245
# 1               4.615325           -6.812256            6.812256
# 2              -5.676262           -1.116343            1.116343
# 3               5.808503           -2.865475            2.865475
# 4              -4.665272           -1.724907            1.724907
# ..                   ...                 ...                 ...
# 259            -5.592703            0.359992           -0.359992
# 260             9.812853           -4.023249            4.023249
# 261             4.337834           -0.937039            0.937039
# 262            -7.402205           -0.124565            0.124565
# 263             5.516979           -1.347083            1.347083
#
#      total_score_diff_algo  best_spread_advantage_algo  \
# 0                -1.831864                    2.067297
# 1                 2.973663                    4.615325
# 2                -0.716653                    5.676262
# 3                -2.850895                    5.808503
# 4                 3.479024                    4.665272
# ..                     ...                         ...
# 259               1.006921                    5.592703
# 260             -13.036947                    9.812853
# 261              -3.511761                    4.337834
# 262               3.833764                    7.402205
# 263               1.443710                    5.516979
#
#     spread_advantage_team_algo  best_spread_advantage_elo  \
# 0                         Away                   1.199245
# 1                         Away                   6.812256
# 2                         Home                   1.116343
# 3                         Away                   2.865475
# 4                         Home                   1.724907
# ..                         ...                        ...
# 259                       Home                   0.359992
# 260                       Away                   4.023249
# 261                       Away                   0.937039
# 262                       Home                   0.124565
# 263                       Away                   1.347083
#
#     spread_advantage_team_elo ou_advantage
# 0                        Away        under
# 1                        Away         over
# 2                        Away        under
# 3                        Away        under
# 4                        Away         over
# ..                        ...          ...
# 259                      Home         over
# 260                      Away        under
# 261                      Away        under
# 262                      Away         over
# 263                      Away         over
#
# [264 rows x 85 columns]

# %%
point_spread_results = point_spread_results[['season', 'week', 'Home Team', 'Away Team', 'home_score', 'away_score',
                                            'home_score_pred', 'away_score_pred', 'total_score', 'total_score_pred', 
                                            'home_spread_algo', 'away_spread_algo', 'home_line_diff_algo', 
                                            'away_line_diff_algo', 'total_score_diff_algo', 'best_spread_advantage_algo',
                                            'spread_advantage_team_algo', 'ou_advantage', 'Home Spread Bet Return',
                                            'Away Spread Bet Return', 'over_bet_return', 'under_bet_return']]

# %%
moneyline_results = moneyline_results[['season', 'week', 'Home Team', 'Away Team', 'home_score', 'away_score',
                                      'implied_prob_home_open', 'implied_prob_away_open', 'home_win_prob', 
                                      'away_win_prob', 'best_prob_advantage_algo', 'advantage_team_algo',
                                      'Home ML Bet Return', 'Away ML Bet Return']]

# %%
point_spread_results
# Out:
#      season  week                 Home Team             Away Team  home_score  \
# 0      2021    19          Los Angeles Rams     Arizona Cardinals          34
# 1      2021    19        Kansas City Chiefs   Pittsburgh Steelers          42
# 2      2021    19            Dallas Cowboys   San Francisco 49ers          17
# 3      2021    19      Tampa Bay Buccaneers   Philadelphia Eagles          31
# 4      2021    19             Buffalo Bills  New England Patriots          47
# ..      ...   ...                       ...                   ...         ...
# 259    2021     1             Detroit Lions   San Francisco 49ers          33
# 260    2021     1        Indianapolis Colts      Seattle Seahawks          16
# 261    2021     1          Tennessee Titans     Arizona Cardinals          13
# 262    2021     1  Washington Football Team  Los Angeles Chargers          16
# 263    2021     1      Tampa Bay Buccaneers        Dallas Cowboys          31
#
#      away_score  home_score_pred  away_score_pred  total_score  \
# 0            11        25.336177        22.903473           45
# 1            21        29.034506        20.149831           63
# 2            23        29.204910        20.528647           40
# 3            15        24.252277        21.560780           46
# 4            17        27.971527        18.806254           64
# ..          ...              ...              ...          ...
# 259          41        22.345221        24.252518           74
# 260          28        15.851038        22.663891           44
# 261          38        23.469574        24.807407           51
# 262          20        27.242985        20.840780           36
# 263          29        27.038755        26.055734           60
#
#      total_score_pred  home_spread_algo  away_spread_algo  \
# 0           48.668136         -2.432703          2.432703
# 1           49.473663         -8.884675          8.884675
# 2           49.783347         -8.676262          8.676262
# 3           46.149105         -2.691497          2.691497
# 4           46.979024         -9.165272          9.165272
# ..                ...               ...               ...
# 259         47.006921          1.907297         -1.907297
# 260         38.963053          6.812853         -6.812853
# 261         47.488239          1.337834         -1.337834
# 262         48.333764         -6.402205          6.402205
# 263         52.943710         -0.983021          0.983021
#
#      home_line_diff_algo  away_line_diff_algo  total_score_diff_algo  \
# 0              -2.067297             2.067297              -1.831864
# 1              -4.615325             4.615325               2.973663
# 2               5.676262            -5.676262              -0.716653
# 3              -5.808503             5.808503              -2.850895
# 4               4.665272            -4.665272               3.479024
# ..                   ...                  ...                    ...
# 259             5.592703            -5.592703               1.006921
# 260            -9.812853             9.812853             -13.036947
# 261            -4.337834             4.337834              -3.511761
# 262             7.402205            -7.402205               3.833764
# 263            -5.516979             5.516979               1.443710
#
#      best_spread_advantage_algo spread_advantage_team_algo ou_advantage  \
# 0                      2.067297                       Away        under
# 1                      4.615325                       Away         over
# 2                      5.676262                       Home        under
# 3                      5.808503                       Away        under
# 4                      4.665272                       Home         over
# ..                          ...                        ...          ...
# 259                    5.592703                       Home         over
# 260                    9.812853                       Away        under
# 261                    4.337834                       Away        under
# 262                    7.402205                       Home         over
# 263                    5.516979                       Away         over
#
#      Home Spread Bet Return  Away Spread Bet Return  over_bet_return  \
# 0                     90.09                 -100.00          -100.00
# 1                     90.09                 -100.00            90.09
# 2                   -100.00                   90.09          -100.00
# 3                     90.09                 -100.00          -100.00
# 4                     90.09                 -100.00            90.09
# ..                      ...                     ...              ...
# 259                 -100.00                   90.09            90.09
# 260                 -100.00                   80.00          -100.00
# 261                 -100.00                   83.33             0.00
# 262                 -100.00                   90.09          -100.00
# 263                 -100.00                   90.09            90.09
#
#      under_bet_return
# 0               90.09
# 1             -100.00
# 2               90.09
# 3               90.09
# 4             -100.00
# ..                ...
# 259           -100.00
# 260             90.09
# 261              0.00
# 262             90.09
# 263           -100.00
#
# [264 rows x 22 columns]

# %%
moneyline_results
# Out:
#      season  week                 Home Team             Away Team  home_score  \
# 0      2021    19          Los Angeles Rams     Arizona Cardinals          34
# 1      2021    19        Kansas City Chiefs   Pittsburgh Steelers          42
# 2      2021    19            Dallas Cowboys   San Francisco 49ers          17
# 3      2021    19      Tampa Bay Buccaneers   Philadelphia Eagles          31
# 4      2021    19             Buffalo Bills  New England Patriots          47
# ..      ...   ...                       ...                   ...         ...
# 259    2021     1             Detroit Lions   San Francisco 49ers          33
# 260    2021     1        Indianapolis Colts      Seattle Seahawks          16
# 261    2021     1          Tennessee Titans     Arizona Cardinals          13
# 262    2021     1  Washington Football Team  Los Angeles Chargers          16
# 263    2021     1      Tampa Bay Buccaneers        Dallas Cowboys          31
#
#      away_score  implied_prob_home_open  implied_prob_away_open  \
# 0            11                0.666667                0.370370
# 1            21                0.877150                0.166667
# 2            23                0.616858                0.416667
# 3            15                0.800000                0.238095
# 4            17                0.680511                0.363636
# ..          ...                     ...                     ...
# 259          41                0.235294                0.813084
# 260          28                0.595142                0.444444
# 261          38                0.585062                0.454545
# 262          20                0.487805                0.555556
# 263          29                0.729730                0.312500
#
#      home_win_prob  away_win_prob  best_prob_advantage_algo  \
# 0         0.621341       0.378659                  0.008288
# 1         0.774682       0.225318                  0.058652
# 2         0.720499       0.279501                  0.103641
# 3         0.616480       0.383520                  0.145425
# 4         0.792161       0.207838                  0.111650
# ..             ...            ...                       ...
# 259       0.280711       0.719289                  0.045417
# 260       0.214556       0.785444                  0.341000
# 261       0.555905       0.444095                 -0.010451
# 262       0.441076       0.558924                  0.003368
# 263       0.548002       0.451998                  0.139498
#
#     advantage_team_algo  Home ML Bet Return  Away ML Bet Return
# 0                  away               50.00             -100.00
# 1                  away               14.01             -100.00
# 2                  home             -100.00              140.00
# 3                  away               25.00             -100.00
# 4                  home               46.95             -100.00
# ..                  ...                 ...                 ...
# 259                home             -100.00               22.99
# 260                away             -100.00              125.00
# 261                away             -100.00              120.00
# 262                away             -100.00               80.00
# 263                away               37.04             -100.00
#
# [264 rows x 14 columns]

# %%
combined_results = point_spread_results.merge(moneyline_results)

# %%
combined_results[(combined_results.home_spread_algo<0) & (combined_results.home_win_prob < .5)
                & (combined_results.home_score<combined_results.away_score)]
# Out:
#      season  week                 Home Team             Away Team  home_score  \
# 69     2021    14        Cincinnati Bengals   San Francisco 49ers          23
# 89     2021    13        Cincinnati Bengals  Los Angeles Chargers          22
# 142    2021     9         Carolina Panthers  New England Patriots           6
# 159    2021     8             Detroit Lions   Philadelphia Eagles           6
# 162    2021     8         Arizona Cardinals     Green Bay Packers          21
# 164    2021     7       San Francisco 49ers    Indianapolis Colts          18
# 180    2021     6          Cleveland Browns     Arizona Cardinals          14
# 230    2021     3        Kansas City Chiefs  Los Angeles Chargers          24
# 233    2021     3       Pittsburgh Steelers    Cincinnati Bengals          10
# 248    2021     2       Philadelphia Eagles   San Francisco 49ers          11
# 249    2021     2       Pittsburgh Steelers     Las Vegas Raiders          17
# 262    2021     1  Washington Football Team  Los Angeles Chargers          16
#
#      away_score  home_score_pred  away_score_pred  total_score  \
# 69           26        21.386625        21.078495           49
# 89           41        24.702142        21.264571           63
# 142          24        22.316315        21.669061           30
# 159          44        24.404394        21.693162           50
# 162          24        26.905928        23.569330           45
# 164          30        24.946698        22.589936           48
# 180          37        24.360520        23.465952           51
# 230          30        27.221474        26.241406           54
# 233          24        23.768454        22.821958           34
# 248          17        22.876305        22.758035           28
# 249          26        25.356580        24.849457           43
# 262          20        27.242985        20.840780           36
#
#      total_score_pred  home_spread_algo  away_spread_algo  \
# 69          41.515928         -0.308130          0.308130
# 89          45.802599         -3.437572          3.437572
# 142         43.831255         -0.647253          0.647253
# 159         46.042717         -2.711231          2.711231
# 162         50.464677         -3.336599          3.336599
# 164         47.471000         -2.356762          2.356762
# 180         47.523042         -0.894569          0.894569
# 230         53.268263         -0.980068          0.980068
# 233         46.934788         -0.946496          0.946496
# 248         45.949347         -0.118270          0.118270
# 249         49.782055         -0.507123          0.507123
# 262         48.333764         -6.402205          6.402205
#
#      home_line_diff_algo  away_line_diff_algo  total_score_diff_algo  \
# 69             -0.691870             0.691870              -5.984072
# 89              0.937572            -0.937572              -4.697401
# 142             3.147253            -3.147253               0.831255
# 159             5.711231            -5.711231              -2.457283
# 162            -0.163401             0.163401              -3.035323
# 164            -1.643238             1.643238               2.971000
# 180            -2.105431             2.105431              -6.476958
# 230            -5.519932             5.519932              -2.231737
# 233            -3.553504             3.553504               2.934788
# 248             3.618270            -3.618270              -4.050653
# 249            -5.492877             5.492877               2.282055
# 262             7.402205            -7.402205               3.833764
#
#      best_spread_advantage_algo spread_advantage_team_algo ou_advantage  \
# 69                     0.691870                       Away        under
# 89                     0.937572                       Home        under
# 142                    3.147253                       Home         over
# 159                    5.711231                       Home        under
# 162                    0.163401                       Away        under
# 164                    1.643238                       Away         over
# 180                    2.105431                       Away        under
# 230                    5.519932                       Away        under
# 233                    3.553504                       Away         over
# 248                    3.618270                       Home        under
# 249                    5.492877                       Away         over
# 262                    7.402205                       Home         over
#
#      Home Spread Bet Return  Away Spread Bet Return  over_bet_return  \
# 69                   -100.0                   86.21            90.09
# 89                   -100.0                   90.09            90.09
# 142                  -100.0                   75.76          -100.00
# 159                  -100.0                   86.21            95.24
# 162                  -100.0                   90.09          -100.00
# 164                  -100.0                   90.09            90.09
# 180                  -100.0                   80.00          -100.00
# 230                  -100.0                   90.09          -100.00
# 233                  -100.0                   90.09          -100.00
# 248                  -100.0                   90.09          -100.00
# 249                  -100.0                   90.09          -100.00
# 262                  -100.0                   90.09          -100.00
#
#      under_bet_return  implied_prob_home_open  implied_prob_away_open  \
# 69            -100.00                0.537037                0.512195
# 89            -100.00                0.585062                0.454545
# 142             95.24                0.434783                0.603175
# 159           -100.00                0.392157                0.636364
# 162             90.09                0.649123                0.377358
# 164           -100.00                0.666667                0.370370
# 180             95.24                0.616858                0.416667
# 230             90.09                0.751861                0.294118
# 233             90.09                0.689441                0.357143
# 248             90.09                0.384615                0.645390
# 249             90.09                0.729730                0.312500
# 262             90.09                0.487805                0.555556
#
#      home_win_prob  away_win_prob  best_prob_advantage_algo  \
# 69        0.211227       0.788773                  0.276578
# 89        0.471577       0.528423                  0.073878
# 142       0.472045       0.527955                  0.037262
# 159       0.457076       0.542924                  0.064919
# 162       0.486332       0.513668                  0.136310
# 164       0.417335       0.582665                  0.212295
# 180       0.418524       0.581476                  0.164809
# 230       0.485886       0.514114                  0.219997
# 233       0.289475       0.710525                  0.353382
# 248       0.454545       0.545455                  0.069930
# 249       0.294873       0.705126                  0.392626
# 262       0.441076       0.558924                  0.003368
#
#     advantage_team_algo  Home ML Bet Return  Away ML Bet Return
# 69                 away              -100.0               95.24
# 89                 away              -100.0              120.00
# 142                home              -100.0               65.79
# 159                home              -100.0               57.14
# 162                away              -100.0              165.00
# 164                away              -100.0              170.00
# 180                away              -100.0              140.00
# 230                away              -100.0              240.00
# 233                away              -100.0              180.00
# 248                home              -100.0               54.95
# 249                away              -100.0              220.00
# 262                away              -100.0               80.00

# %%
def get_return_proportional_ml(game):
    
    bet_weight = 0
    
    if .03 <= game.best_prob_advantage_algo < .05:
        bet_weight = 1
    elif .05 <= game.best_prob_advantage_algo < .1:
        bet_weight = 2
    elif .1<= game.best_prob_advantage_algo < .15:
        bet_weight = 3
    elif .15 <= game.best_prob_advantage_algo < .2:
        bet_weight = 4
    elif game.best_prob_advantage_algo >= .2 :
        bet_weight = 5
        
    if game.advantage_team_algo == 'home':
        return bet_weight * game['Home ML Bet Return'], bet_weight * 100
    else:
        return bet_weight * game['Away ML Bet Return'], bet_weight * 100
    
def get_return_proportional_ou(game):
    
    bet_weight = 0
    
    if 1 <= abs(game.total_score_diff_algo) < 2:
        bet_weight = 1
    elif 2 <= abs(game.total_score_diff_algo) < 3:
        bet_weight = 2
    elif 3 <= abs(game.total_score_diff_algo) < 4:
        bet_weight = 3
    elif 4 <= abs(game.total_score_diff_algo) < 5:
        bet_weight = 4
    elif abs(game.total_score_diff_algo) >= 5 :
        bet_weight = 5
        
    return bet_weight * game['{}_bet_return'.format(game.ou_advantage)], bet_weight*100


def get_return_proportional_spread(game):
    
    bet_weight = 0
    
    if 3 <= game.best_spread_advantage_algo < 4:
        bet_weight = 1
    elif 4 <= game.best_spread_advantage_algo < 5:
        bet_weight = 2
    elif 5 <= game.best_spread_advantage_algo < 6:
        bet_weight = 3
    elif 6 <= game.best_spread_advantage_algo < 7:
        bet_weight = 4
    elif game.best_spread_advantage_algo >= 7 :
        bet_weight = 5
        
    if game.spread_advantage_team_algo == 'Home':
        return bet_weight * game['Home Spread Bet Return'], bet_weight * 100
    else:
        return bet_weight * game['Away Spread Bet Return'], bet_weight * 100
    
gambling_df = combined_results.copy()
gambling_df[['moneyline_returns', 'moneyline_wagered']] = gambling_df.apply(lambda x: get_return_proportional_ml(x), axis=1, result_type='expand')
gambling_df[['spread_returns', 'spread_wagered']] = gambling_df.apply(lambda x: get_return_proportional_spread(x), axis=1, result_type='expand')
gambling_df[['ou_returns', 'ou_wagered']] = gambling_df.apply(lambda x: get_return_proportional_ou(x), axis=1, result_type='expand')
gambling_df['total_returns'] = gambling_df.moneyline_returns + gambling_df.spread_returns + gambling_df.ou_returns
gambling_df['total_wagered'] = gambling_df.moneyline_wagered + gambling_df.spread_wagered + gambling_df.ou_wagered

gambling_df
# Out:
#      season  week                 Home Team             Away Team  home_score  \
# 0      2021    19          Los Angeles Rams     Arizona Cardinals          34
# 1      2021    19        Kansas City Chiefs   Pittsburgh Steelers          42
# 2      2021    19            Dallas Cowboys   San Francisco 49ers          17
# 3      2021    19      Tampa Bay Buccaneers   Philadelphia Eagles          31
# 4      2021    19             Buffalo Bills  New England Patriots          47
# ..      ...   ...                       ...                   ...         ...
# 259    2021     1             Detroit Lions   San Francisco 49ers          33
# 260    2021     1        Indianapolis Colts      Seattle Seahawks          16
# 261    2021     1          Tennessee Titans     Arizona Cardinals          13
# 262    2021     1  Washington Football Team  Los Angeles Chargers          16
# 263    2021     1      Tampa Bay Buccaneers        Dallas Cowboys          31
#
#      away_score  home_score_pred  away_score_pred  total_score  \
# 0            11        25.336177        22.903473           45
# 1            21        29.034506        20.149831           63
# 2            23        29.204910        20.528647           40
# 3            15        24.252277        21.560780           46
# 4            17        27.971527        18.806254           64
# ..          ...              ...              ...          ...
# 259          41        22.345221        24.252518           74
# 260          28        15.851038        22.663891           44
# 261          38        23.469574        24.807407           51
# 262          20        27.242985        20.840780           36
# 263          29        27.038755        26.055734           60
#
#      total_score_pred  home_spread_algo  away_spread_algo  \
# 0           48.668136         -2.432703          2.432703
# 1           49.473663         -8.884675          8.884675
# 2           49.783347         -8.676262          8.676262
# 3           46.149105         -2.691497          2.691497
# 4           46.979024         -9.165272          9.165272
# ..                ...               ...               ...
# 259         47.006921          1.907297         -1.907297
# 260         38.963053          6.812853         -6.812853
# 261         47.488239          1.337834         -1.337834
# 262         48.333764         -6.402205          6.402205
# 263         52.943710         -0.983021          0.983021
#
#      home_line_diff_algo  away_line_diff_algo  total_score_diff_algo  \
# 0              -2.067297             2.067297              -1.831864
# 1              -4.615325             4.615325               2.973663
# 2               5.676262            -5.676262              -0.716653
# 3              -5.808503             5.808503              -2.850895
# 4               4.665272            -4.665272               3.479024
# ..                   ...                  ...                    ...
# 259             5.592703            -5.592703               1.006921
# 260            -9.812853             9.812853             -13.036947
# 261            -4.337834             4.337834              -3.511761
# 262             7.402205            -7.402205               3.833764
# 263            -5.516979             5.516979               1.443710
#
#      best_spread_advantage_algo spread_advantage_team_algo ou_advantage  \
# 0                      2.067297                       Away        under
# 1                      4.615325                       Away         over
# 2                      5.676262                       Home        under
# 3                      5.808503                       Away        under
# 4                      4.665272                       Home         over
# ..                          ...                        ...          ...
# 259                    5.592703                       Home         over
# 260                    9.812853                       Away        under
# 261                    4.337834                       Away        under
# 262                    7.402205                       Home         over
# 263                    5.516979                       Away         over
#
#      Home Spread Bet Return  Away Spread Bet Return  over_bet_return  \
# 0                     90.09                 -100.00          -100.00
# 1                     90.09                 -100.00            90.09
# 2                   -100.00                   90.09          -100.00
# 3                     90.09                 -100.00          -100.00
# 4                     90.09                 -100.00            90.09
# ..                      ...                     ...              ...
# 259                 -100.00                   90.09            90.09
# 260                 -100.00                   80.00          -100.00
# 261                 -100.00                   83.33             0.00
# 262                 -100.00                   90.09          -100.00
# 263                 -100.00                   90.09            90.09
#
#      under_bet_return  implied_prob_home_open  implied_prob_away_open  \
# 0               90.09                0.666667                0.370370
# 1             -100.00                0.877150                0.166667
# 2               90.09                0.616858                0.416667
# 3               90.09                0.800000                0.238095
# 4             -100.00                0.680511                0.363636
# ..                ...                     ...                     ...
# 259           -100.00                0.235294                0.813084
# 260             90.09                0.595142                0.444444
# 261              0.00                0.585062                0.454545
# 262             90.09                0.487805                0.555556
# 263           -100.00                0.729730                0.312500
#
#      home_win_prob  away_win_prob  best_prob_advantage_algo  \
# 0         0.621341       0.378659                  0.008288
# 1         0.774682       0.225318                  0.058652
# 2         0.720499       0.279501                  0.103641
# 3         0.616480       0.383520                  0.145425
# 4         0.792161       0.207838                  0.111650
# ..             ...            ...                       ...
# 259       0.280711       0.719289                  0.045417
# 260       0.214556       0.785444                  0.341000
# 261       0.555905       0.444095                 -0.010451
# 262       0.441076       0.558924                  0.003368
# 263       0.548002       0.451998                  0.139498
#
#     advantage_team_algo  Home ML Bet Return  Away ML Bet Return  \
# 0                  away               50.00             -100.00
# 1                  away               14.01             -100.00
# 2                  home             -100.00              140.00
# 3                  away               25.00             -100.00
# 4                  home               46.95             -100.00
# ..                  ...                 ...                 ...
# 259                home             -100.00               22.99
# 260                away             -100.00              125.00
# 261                away             -100.00              120.00
# 262                away             -100.00               80.00
# 263                away               37.04             -100.00
#
#      moneyline_returns  moneyline_wagered  spread_returns  spread_wagered  \
# 0                -0.00                0.0           -0.00             0.0
# 1              -200.00              200.0         -200.00           200.0
# 2              -300.00              300.0         -300.00           300.0
# 3              -300.00              300.0         -300.00           300.0
# 4               140.85              300.0          180.18           200.0
# ..                 ...                ...             ...             ...
# 259            -100.00              100.0         -300.00           300.0
# 260             625.00              500.0          400.00           500.0
# 261               0.00                0.0          166.66           200.0
# 262               0.00                0.0         -500.00           500.0
# 263            -300.00              300.0          270.27           300.0
#
#      ou_returns  ou_wagered  total_returns  total_wagered
# 0         90.09       100.0          90.09          100.0
# 1        180.18       200.0        -219.82          600.0
# 2          0.00         0.0        -600.00          600.0
# 3        180.18       200.0        -419.82          800.0
# 4        270.27       300.0         591.30          800.0
# ..          ...         ...            ...            ...
# 259       90.09       100.0        -309.91          500.0
# 260      450.45       500.0        1475.45         1500.0
# 261        0.00       300.0         166.66          500.0
# 262     -300.00       300.0        -800.00          800.0
# 263       90.09       100.0          60.36          700.0
#
# [264 rows x 38 columns]

# %%
# Look at subsets of gambling_df

# All games
# gambling_df

# All games where moneyline and spread are not both gambled on if they dont match
gambling_df = gambling_df[~((((gambling_df.spread_advantage_team_algo == 'Away') & (gambling_df.advantage_team_algo == 'home')) 
                         | ((gambling_df.spread_advantage_team_algo == 'Home') & (gambling_df.advantage_team_algo == 'away')))
                         & ((gambling_df.moneyline_wagered>0) & (gambling_df.spread_wagered>0)))]

# Games where moneyline and point spread dont match up (away ml, home spread or vice versa) 
# gambling_df = gambling_df[((gambling_df.home_spread_algo<0) & (gambling_df.home_win_prob<.5)) 
#                          | ((gambling_df.home_spread_algo>0) & (gambling_df.home_win_prob>.5))]

# Games where bets were wagered only on moneyline or point spread, not both 
# gambling_df = gambling_df[((gambling_df.moneyline_wagered<=0) & (gambling_df.spread_wagered>0)) 
#                          | ((gambling_df.moneyline_wagered>0) & (gambling_df.spread_wagered<=0))]

# Games where bets were wagered on both moneyline and point spread
# gambling_df = gambling_df[((gambling_df.moneyline_wagered>0) & (gambling_df.spread_wagered>0))]

# Games where bets were wagered on opposing sides i.e. moneyline home and spread away or vice versa
# gambling_df = gambling_df[((((gambling_df.spread_advantage_team_algo == 'Away') & (gambling_df.advantage_team_algo == 'home')) 
#                          | ((gambling_df.spread_advantage_team_algo == 'Home') & (gambling_df.advantage_team_algo == 'away')))
#                          & ((gambling_df.moneyline_wagered>0) & (gambling_df.spread_wagered>0)))]
gambling_df
# Out:
#      season  week                 Home Team             Away Team  home_score  \
# 0      2021    19          Los Angeles Rams     Arizona Cardinals          34
# 1      2021    19        Kansas City Chiefs   Pittsburgh Steelers          42
# 2      2021    19            Dallas Cowboys   San Francisco 49ers          17
# 3      2021    19      Tampa Bay Buccaneers   Philadelphia Eagles          31
# 4      2021    19             Buffalo Bills  New England Patriots          47
# ..      ...   ...                       ...                   ...         ...
# 259    2021     1             Detroit Lions   San Francisco 49ers          33
# 260    2021     1        Indianapolis Colts      Seattle Seahawks          16
# 261    2021     1          Tennessee Titans     Arizona Cardinals          13
# 262    2021     1  Washington Football Team  Los Angeles Chargers          16
# 263    2021     1      Tampa Bay Buccaneers        Dallas Cowboys          31
#
#      away_score  home_score_pred  away_score_pred  total_score  \
# 0            11        25.336177        22.903473           45
# 1            21        29.034506        20.149831           63
# 2            23        29.204910        20.528647           40
# 3            15        24.252277        21.560780           46
# 4            17        27.971527        18.806254           64
# ..          ...              ...              ...          ...
# 259          41        22.345221        24.252518           74
# 260          28        15.851038        22.663891           44
# 261          38        23.469574        24.807407           51
# 262          20        27.242985        20.840780           36
# 263          29        27.038755        26.055734           60
#
#      total_score_pred  home_spread_algo  away_spread_algo  \
# 0           48.668136         -2.432703          2.432703
# 1           49.473663         -8.884675          8.884675
# 2           49.783347         -8.676262          8.676262
# 3           46.149105         -2.691497          2.691497
# 4           46.979024         -9.165272          9.165272
# ..                ...               ...               ...
# 259         47.006921          1.907297         -1.907297
# 260         38.963053          6.812853         -6.812853
# 261         47.488239          1.337834         -1.337834
# 262         48.333764         -6.402205          6.402205
# 263         52.943710         -0.983021          0.983021
#
#      home_line_diff_algo  away_line_diff_algo  total_score_diff_algo  \
# 0              -2.067297             2.067297              -1.831864
# 1              -4.615325             4.615325               2.973663
# 2               5.676262            -5.676262              -0.716653
# 3              -5.808503             5.808503              -2.850895
# 4               4.665272            -4.665272               3.479024
# ..                   ...                  ...                    ...
# 259             5.592703            -5.592703               1.006921
# 260            -9.812853             9.812853             -13.036947
# 261            -4.337834             4.337834              -3.511761
# 262             7.402205            -7.402205               3.833764
# 263            -5.516979             5.516979               1.443710
#
#      best_spread_advantage_algo spread_advantage_team_algo ou_advantage  \
# 0                      2.067297                       Away        under
# 1                      4.615325                       Away         over
# 2                      5.676262                       Home        under
# 3                      5.808503                       Away        under
# 4                      4.665272                       Home         over
# ..                          ...                        ...          ...
# 259                    5.592703                       Home         over
# 260                    9.812853                       Away        under
# 261                    4.337834                       Away        under
# 262                    7.402205                       Home         over
# 263                    5.516979                       Away         over
#
#      Home Spread Bet Return  Away Spread Bet Return  over_bet_return  \
# 0                     90.09                 -100.00          -100.00
# 1                     90.09                 -100.00            90.09
# 2                   -100.00                   90.09          -100.00
# 3                     90.09                 -100.00          -100.00
# 4                     90.09                 -100.00            90.09
# ..                      ...                     ...              ...
# 259                 -100.00                   90.09            90.09
# 260                 -100.00                   80.00          -100.00
# 261                 -100.00                   83.33             0.00
# 262                 -100.00                   90.09          -100.00
# 263                 -100.00                   90.09            90.09
#
#      under_bet_return  implied_prob_home_open  implied_prob_away_open  \
# 0               90.09                0.666667                0.370370
# 1             -100.00                0.877150                0.166667
# 2               90.09                0.616858                0.416667
# 3               90.09                0.800000                0.238095
# 4             -100.00                0.680511                0.363636
# ..                ...                     ...                     ...
# 259           -100.00                0.235294                0.813084
# 260             90.09                0.595142                0.444444
# 261              0.00                0.585062                0.454545
# 262             90.09                0.487805                0.555556
# 263           -100.00                0.729730                0.312500
#
#      home_win_prob  away_win_prob  best_prob_advantage_algo  \
# 0         0.621341       0.378659                  0.008288
# 1         0.774682       0.225318                  0.058652
# 2         0.720499       0.279501                  0.103641
# 3         0.616480       0.383520                  0.145425
# 4         0.792161       0.207838                  0.111650
# ..             ...            ...                       ...
# 259       0.280711       0.719289                  0.045417
# 260       0.214556       0.785444                  0.341000
# 261       0.555905       0.444095                 -0.010451
# 262       0.441076       0.558924                  0.003368
# 263       0.548002       0.451998                  0.139498
#
#     advantage_team_algo  Home ML Bet Return  Away ML Bet Return  \
# 0                  away               50.00             -100.00
# 1                  away               14.01             -100.00
# 2                  home             -100.00              140.00
# 3                  away               25.00             -100.00
# 4                  home               46.95             -100.00
# ..                  ...                 ...                 ...
# 259                home             -100.00               22.99
# 260                away             -100.00              125.00
# 261                away             -100.00              120.00
# 262                away             -100.00               80.00
# 263                away               37.04             -100.00
#
#      moneyline_returns  moneyline_wagered  spread_returns  spread_wagered  \
# 0                -0.00                0.0           -0.00             0.0
# 1              -200.00              200.0         -200.00           200.0
# 2              -300.00              300.0         -300.00           300.0
# 3              -300.00              300.0         -300.00           300.0
# 4               140.85              300.0          180.18           200.0
# ..                 ...                ...             ...             ...
# 259            -100.00              100.0         -300.00           300.0
# 260             625.00              500.0          400.00           500.0
# 261               0.00                0.0          166.66           200.0
# 262               0.00                0.0         -500.00           500.0
# 263            -300.00              300.0          270.27           300.0
#
#      ou_returns  ou_wagered  total_returns  total_wagered
# 0         90.09       100.0          90.09          100.0
# 1        180.18       200.0        -219.82          600.0
# 2          0.00         0.0        -600.00          600.0
# 3        180.18       200.0        -419.82          800.0
# 4        270.27       300.0         591.30          800.0
# ..          ...         ...            ...            ...
# 259       90.09       100.0        -309.91          500.0
# 260      450.45       500.0        1475.45         1500.0
# 261        0.00       300.0         166.66          500.0
# 262     -300.00       300.0        -800.00          800.0
# 263       90.09       100.0          60.36          700.0
#
# [260 rows x 38 columns]

# %%
# Moneyline returns

gambling_df.groupby(by=['week']).sum()['moneyline_returns'].reset_index().plot.bar(x='week', y='moneyline_returns')

# %%
# Spread returns

gambling_df.groupby(by=['week']).sum()['spread_returns'].reset_index().plot.bar(x='week', y='spread_returns')

# %%
# O/U returns

gambling_df.groupby(by=['week']).sum()['ou_returns'].reset_index().plot.bar(x='week', y='ou_returns')

# %%
# Total Returns 

gambling_df.groupby(by=['week']).sum()['total_returns'].reset_index().plot.bar(x='week', y='total_returns')

# %%
# Total Wagered

gambling_df.groupby(by=['week']).sum()['total_wagered'].reset_index().plot.bar(x='week', y='total_wagered')

# %%
print('Moneyline Returns: {}'.format(gambling_df.sum().moneyline_returns))
print('Point Spread Returns: {}'.format(gambling_df.sum().spread_returns))
print('Over/Under Returns: {}'.format(gambling_df.sum().ou_returns))

print('Total Returns: {}'.format(gambling_df.sum().total_returns))

print('Average Wagered: {}'.format(gambling_df.sum().total_wagered/19))
# Out:
# Moneyline Returns: 7514.63
# Point Spread Returns: 3083.2800000000007
# Over/Under Returns: 5813.1900000000005
# Total Returns: 16411.1
# Average Wagered: 7168.421052631579

# %% [markdown]
# Note: The moneyline and point spread algorithms can sometimes "disagree" with each other, i.e. the moneyline algorithm will predict the home team to win, while the point spread algorithm will predict that the away team should be favored. However, this doesn't seem to be much of an issue, and the bets don't necessarily counteract each other. As an example, take the titans 49ers game from 2021. The point spread algorithm identifies the titans should be favored by a point, when they are actually the underdog, thus indicating that the titans are more likely to win. However, the moneyline algorithm gives the titans only a 44% chance to win, which doesnt match the results of the point spread algorithm. However, the vegas implied odds have the titans at a 40% chance to win. So even though the predictions are conflicting, the actual suggested bets are not, as they have you taking both titans spread and titans moneyline. This scenario happens somewhat often, and doesnt seem to hinder the algorithm performance in any way. In most of these cases, only one of the algorithms is confident enough to place a bet. In most of the cases where both are confident, they usually match like the scenario above. In the rare case where they do not match up, it is not advised to take any of the bets.
